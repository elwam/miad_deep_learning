# %%
# Importar librerias necesarias para el modelo
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
from math import sqrt

from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError

from keras import regularizers

# %% [markdown]
# ### Cargue de datos
#
# Se realiza el cargue de los datos entregados para el proyecto.

# %%
# Cargar los datos
# Cargar los datos nuevamente
train_data = pd.read_csv('trainReg.csv')
test_data = pd.read_csv('testReg.csv')
info_dataset = train_data.shape
print(f'Daset compuesto por {info_dataset[0]} Filas y  {info_dataset[1]} columas.')

# Asegurarse de eliminar 'ID' antes de realizar análisis de correlación
if 'ID' in train_data.columns:
    train_data = train_data.drop(columns=['ID','V3'])
if 'ID' in test_data.columns:
    test_id = test_data['ID']  # Guardar IDs para uso posterior
    test_data = test_data.drop(columns=['ID','V3'])

# Se toman las 12 primeras columnas del SET de datos
datos_principaleS_train = train_data[['Y', 'V1', 'V2', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10','V11', 'V12']]
# Out:
# Daset compuesto por 77779 Filas y  92 columas.

# %% [markdown]
# ### Exploración de los datos para su entendimiento dentro del contexto organizacional

# %%
print("Primeras filas del conjunto de datos:")
train_data.head()
# Out:
# Primeras filas del conjunto de datos:
#       Y        V1       V2        V4        V5       V6        V7        V8  \
# 0  2013  44.81144  0.83826   7.91314  10.94148 -0.04547 -15.16332 -10.47324
# 1  1998  41.99180  7.99976  64.26707  16.54115 -9.28737 -40.73524  33.60440
# 2  1998  42.19196  2.23111  65.07719  24.99746  1.76100   6.66573   3.45778
# 3  1998  39.28634 -1.85716  91.04190   9.08333  0.08502  -5.59216  65.62463
# 4  1998  40.36025  2.94918  53.83723  13.71369 -8.21964 -40.21636  21.22366
#
#          V9       V10  ...       V81        V82        V83        V84  \
# 0  14.17212  10.57382  ...  -8.44873 -230.30484  -40.94698   48.20025
# 1   9.18802  -6.79144  ...  18.68972  -44.06062   52.37792   81.36093
# 2 -24.42779 -18.45069  ...  -3.69878 -118.95712   54.15529  -23.32168
# 3   8.33105  11.70269  ...  20.89044  -18.53135  176.09769  351.33669
# 4  17.16742   0.14463  ...  19.91979   34.59026  -69.83720  102.31946
#
#         V85        V86        V87       V88        V89       V90
# 0  -0.28694  155.76251  -56.23579  13.62599  123.92018  10.02845
# 1 -14.81111  151.66273 -120.61213  10.57519   -3.21078  -1.07438
# 2  -9.65067  -83.83055 -141.17594   7.33084 -275.69714   2.35522
# 3   3.44682  121.69156 -270.43989  12.51659 -140.88884  -0.23476
# 4   8.08807  135.08089 -153.02327   4.09207  -68.33046  -6.19159
#
# [5 rows x 90 columns]

# %%
print("Estadísticas descriptivas:")
datos_principaleS_train.describe()
# Out:
# Estadísticas descriptivas:
#                   Y            V1            V2            V4            V5  \
# count  77779.000000  77779.000000  77779.000000  77779.000000  77779.000000
# mean    2002.308129     43.425185     -0.136720      3.755313     -2.339768
# std       10.811038      6.128869      4.370466     17.609183     14.483975
# min     1926.000000      4.836880    -69.680870   -165.221610   -121.475340
# 25%     1998.000000     40.060315     -2.612435     -7.016240    -10.685075
# 50%     2006.000000     44.323850     -0.063000      2.022100     -2.054560
# 75%     2010.000000     47.900080      2.465950     12.776450      6.423900
# max     2014.000000     60.034010     23.815260    274.658580    160.815220
#
#                  V6            V7            V8            V9           V10  \
# count  77779.000000  77779.000000  77779.000000  77779.000000  77779.000000
# mean      -1.643095     -6.814997     -9.587264      3.749572      1.948512
# std        7.898574     22.980515     12.911914     10.638581      6.430093
# min      -72.503850   -152.407550    -70.693420   -119.487530    -41.631660
# 25%       -6.300690    -21.265305    -18.583065     -2.289400     -2.270755
# 50%       -1.586240     -6.307610    -11.238330      3.928440      1.897680
# 75%        3.077055      7.617995     -2.329330     10.039325      6.163805
# max       68.447960    262.068870    112.971410     80.787120     39.976830
#
#                 V11           V12
# count  77779.000000  77779.000000
# mean       8.674857      1.977878
# std       35.096050     52.159787
# min     -249.107450   -329.571380
# 25%      -11.115595    -25.009270
# 50%       10.894150      9.370100
# 75%       29.762770     37.117870
# max      262.283040    304.266390

# %%
# Visualizar histogramas de las variables
train_data.hist(figsize=(15, 10))
plt.subplots_adjust(left=0.1, right=0.9, top=2, bottom=0.1, hspace=0.3, wspace=0.3)
plt.suptitle('Histogramas de las variables', fontsize=12)
plt.show()

# %%
import seaborn as sns
# Calcular la matriz de correlación
correlation_matrix = datos_principaleS_train.corr()


# Visualizar el correlograma con paleta de colores 'RdBu'
sns.heatmap(correlation_matrix, annot=True, cmap='RdBu', fmt=".2f")
plt.title('Matriz de correlación Principales Variables ', fontsize=12)
plt.show()

# %%
# Visualizar la distribución de la variable objetivo (Año)
plt.figure(figsize=(8, 6))
sns.histplot(datos_principaleS_train['Y'], bins=30, kde=True)
plt.title('Distribución de Año de Lanzamiento')
plt.xlabel('Año')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# c:\Users\Usuario\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Análisis del set de datos
#
# Se realiza el análisis exploratorio del set de datos destinado para entrenamiento del cual se observa lo siguiente:
#
# #### Descripción del set de datos:
#
# * El set de datos está compuesto por 77.779 filas y 92 columnas.
# * Se eliminaron las columnas ID y V3 antes del análisis.
#     * La columna ID se eliminó ya que es el identificador único de cada canción en el set de datos.
#     * La columna V3 se eliminó ya que no contiene valores.
#
# #### Análisis descriptivo:
#
# * Se realizo el análisis sobre las 12 primeras variables del set de datos, de las cuales es posible observar que tienen una distirbución normal.
#
#
# #### Análisis de correlación:
#
# * Al realizar el análisis de correlación de variables se detecta un correlación positiva entre las variables V1, V2, V4 y V5.
#
#
# #### Distribución temporal de las canciones:
#
# * Sobre las canciones disponibles en el set de datos se puede observar que la mayoría se encuentran sobre los años 2000, esto indica que es posible que se trate de timbres similares o recientes.

# %% [markdown]
# ### Preparación de los datos para poder utilizarlos como entrada para modelos predictivos

# %%
# Función para crear características
def create_features(data):
    # Adjusted range to exclude 'V3'
    timbre_cols = [f"V{i}" for i in range(1, 13) if i != 3]
    
    # Check if all required timbre columns except V3 exist
    if all(col in data.columns for col in timbre_cols):
        data['mean_timbre'] = data[timbre_cols].mean(axis=1)
        data['median_timbre'] = data[timbre_cols].median(axis=1)
        data['std_timbre'] = data[timbre_cols].std(axis=1)
        data['sum_timbre'] = data[timbre_cols].sum(axis=1)
        data['max_timbre'] = data[timbre_cols].max(axis=1)
        data['min_timbre'] = data[timbre_cols].min(axis=1)
        data['prod_timbre'] = data[timbre_cols].prod(axis=1)
    else:
        print("Algunas columnas necesarias (V1, V2, V4 a V12) no existen en el DataFrame")
    # Check if all covariance columns (V13 to V90) exist
    if all(f"V{i}" in data.columns for i in range(13, 91)):
        covariance_cols = [f"V{i}" for i in range(13, 91)]
        data['mean_covariance'] = data[covariance_cols].mean(axis=1)
        data['median_covariance'] = data[covariance_cols].median(axis=1)
        data['std_covariance'] = data[covariance_cols].std(axis=1)
        data['sum_covariance'] = data[covariance_cols].sum(axis=1)
        data['max_covariance'] = data[covariance_cols].max(axis=1)
        data['min_covariance'] = data[covariance_cols].min(axis=1)
        # Using logarithmic addition to prevent overflow in product
        data['prod_covariance'] = np.exp(data[covariance_cols].apply(np.log).sum(axis=1))
    else:
        print("Algunas columnas de V13 a V90 no existen en el DataFrame")

    return data
# Aplicar la creación de características
train_data = create_features(train_data)
test_data = create_features(test_data)

# %%
import matplotlib.pyplot as plt
def plot_corr(data):
    # Calculate the correlation matrix
    correlation_matrix = data.corr()
    
    # Extended list of custom variables including new stats
    custom_vars = [
        'mean_timbre', 'median_timbre', 'std_timbre', 'sum_timbre', 'max_timbre', 'min_timbre', 'prod_timbre',
        'mean_covariance', 'median_covariance', 'std_covariance', 'sum_covariance', 'max_covariance', 'min_covariance', 'prod_covariance'
    ]
    
    # Extract correlation with 'Y' for custom variables only
    correlation_with_y_custom = correlation_matrix['Y'][custom_vars]

    # Plotting
    plt.figure(figsize=(15, 8))  # Increased size for better visibility with more variables
    correlation_with_y_custom.plot(kind='bar', color='skyblue')
    plt.title('Correlation of "Y" with Custom Variables Including New Stats')
    plt.xlabel('Variables')
    plt.ylabel('Correlation Coefficient')
    plt.grid(True)
    plt.axhline(0, color='gray', linewidth=0.5)  # Add a line at zero for reference
    plt.show()

# Note: All function calls have been commented out. Uncomment when needed for execution.

plot_corr(train_data)

# %%
# Calculando la correlación entre todas las características y la variable objetivo
correlation_matrix = train_data.corr()
target_correlation = correlation_matrix['Y'].sort_values(ascending=False)
correlation_matrix
correlation_matrix = train_data.corr()
target_correlation = correlation_matrix['Y'].sort_values(ascending=False)
target_correlation

# Identificando características con baja correlación con el objetivo (umbral de 0.01)
important_features = target_correlation[abs(target_correlation) > 0.01]

# Identificar características altamente correlacionadas entre sí para evitar multicolinealidad
# Usaremos un umbral de 0.7 para alta correlación
high_corr_matrix = correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool))

to_drop = [column for column in high_corr_matrix.columns if any(high_corr_matrix[column] > 0.7)]

# Filtrar la lista de características importantes eliminando las altamente correlacionadas
selected_features = important_features.index.difference(to_drop)
selected_features
selected_features2 = selected_features.difference(['Y'])
selected_features2
train_data = train_data[selected_features]
test_data = test_data[selected_features2]

# %%
# Divisón del set de datos 

# Asegurarse de eliminar 'ID' antes de realizar análisis de correlación
train_data.drop(columns=['ID'], inplace=True, errors='ignore')
test_data.drop(columns=['ID'], inplace=True, errors='ignore')

# División de datos
X_train, X_val, y_train, y_val = train_test_split(train_data.drop(columns=['Y']), train_data['Y'], test_size=0.15, random_state=42)

# Escalado de datos
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# Comprobar NaN en datos escalados
if np.isnan(X_train_scaled).any() or np.isnan(X_val_scaled).any():
    raise ValueError("Los datos escalados contienen NaN")
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_35364\948552729.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.drop(columns=['ID'], inplace=True, errors='ignore')

# %% [markdown]
# ## Análisis preparación del set de datos
#
# Tomando como base las primeras 12 variables del conjunto de datos, hemos calculado nuevas variables que servirán como predictores durante el proceso de entrenamiento.
#
# 1. mean_timbre (Timbre promedio)
# 2. median_timbre (Timbre mediano)
# 3. std_timbre (Desviación estándar del timbre)
# 4. sum_timbre (Suma del timbre)
# 5. max_timbre (Máximo del timbre)
# 6. min_timbre (Mínimo del timbre)
# 7. prod_timbre (Producto del timbre)
# 8. mean_covariance (Covarianza promedio)
# 9. median_covariance (Covarianza mediana)
# 10. std_covariance (Desviación estándar de la covarianza)
# 11. sum_covariance (Suma de la covarianza)
# 12. max_covariance (Máximo de la covarianza)
# 13. min_covariance (Mínimo de la covarianza)
# 14. prod_covariance (Producto de la covarianza)
#
# Una vez que se han generado estas características adicionales, se procedió a estandarizar las variables predictoras utilizando StandardScaler. Esta estandarización ajusta las variables para que tengan una media de 0 y una desviación estándar de 1, lo que facilita el proceso de entrenamiento de modelos y asegura una mejor convergencia durante el proceso de optimización.

# %% [markdown]
# ### Análisis preliminar de selección de modelos relevantes para responder a la pregunta

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

def OptimizedModel(epocas, optimizador, batch_sz, XTrain, YTrain, XTest, YTest):


    XTrainBest = XTrain
    XTestBest = XTest

    model = Sequential()
    model.add(Dense(502, activation='relu', input_shape=(XTrainBest.shape[1],)))
    model.add(Dense(256, activation='elu'))
    model.add(Dense(128, activation='elu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='elu'))
    model.add(Dense(1, activation='linear'))


    # Compile the model
    model.compile(loss=MeanSquaredError(), optimizer=optimizador, metrics=[RootMeanSquaredError()])

    # Train the model
    model.fit(XTrainBest, YTrain, epochs=epocas, batch_size=batch_sz, validation_split=0.2, verbose=1, callbacks=[es])


    # Evaluate the model
    resultado = model.evaluate(XTestBest, YTest, return_dict=True)

    return epocas, optimizador, resultado.get('root_mean_squared_error'), batch_sz



def OptimizedModelAdam(epocas, batch_sz, XTrain, YTrain, XTest, YTest, learning_rate):

    XTrainBest = XTrain
    XTestBest = XTest

    model = Sequential()
    model.add(Dense(502, activation='relu', input_shape=(XTrainBest.shape[1],)))
    model.add(Dense(256, activation='elu'))
    model.add(Dense(128, activation='elu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='elu'))
    model.add(Dense(1, activation='linear'))

    
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(loss=MeanSquaredError(), optimizer=optimizer, metrics=[RootMeanSquaredError()])

    # Train the model
    model.fit(XTrainBest, YTrain, epochs=epocas, batch_size=batch_sz, validation_split=0.2, verbose=1, callbacks=[es])


    # Evaluate the model
    resultado = model.evaluate(XTestBest, YTest, return_dict=True)

    return epocas, resultado.get('root_mean_squared_error'), batch_sz, learning_rate

# %%
resultado = list()

epocas = [50, 100]
optimizador= ['Adam',  'Adadelta', 'Adamax']
batch_size = [32,64]

for o in optimizador:
    for e in epocas:
        for b in batch_size:
                ret = OptimizedModel(e, o, b, X_train_scaled, y_train, X_val_scaled, y_val)
                resultado.append([ret])
# Out:
# Epoch 1/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 453689.7812 - root_mean_squared_error: 585.3382 - val_loss: 150.8682 - val_root_mean_squared_error: 12.2828
# Epoch 2/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 107.3688 - root_mean_squared_error: 10.3602 - val_loss: 111.4391 - val_root_mean_squared_error: 10.5565
# Epoch 3/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 99.3189 - root_mean_squared_error: 9.9652 - val_loss: 130.6052 - val_root_mean_squared_error: 11.4283
# Epoch 4/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 110.0464 - root_mean_squared_error: 10.4895 - val_loss: 98.2610 - val_root_mean_squared_error: 9.9127
# Epoch 5/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 114.2407 - root_mean_squared_error: 10.6789 - val_loss: 183.1783 - val_root_mean_squared_error: 13.5343
# Epoch 6/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 114.2879 - root_mean_squared_error: 10.6878 - val_loss: 95.4484 - val_root_mean_squared_error: 9.7698
# Epoch 7/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 113.0526 - root_mean_squared_error: 10.6300 - val_loss: 79.9520 - val_root_mean_squared_error: 8.9416
# Epoch 8/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 97.6125 - root_mean_squared_error: 9.8773 - val_loss: 79.1877 - val_root_mean_squared_error: 8.8987
# Epoch 9/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 100.6223 - root_mean_squared_error: 10.0278 - val_loss: 117.8580 - val_root_mean_squared_error: 10.8562
# Epoch 10/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 102.7354 - root_mean_squared_error: 10.1343 - val_loss: 79.5584 - val_root_mean_squared_error: 8.9196
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 77.5288 - root_mean_squared_error: 8.8032
# Epoch 1/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 720256.0000 - root_mean_squared_error: 763.8616 - val_loss: 1755.5740 - val_root_mean_squared_error: 41.8996
# Epoch 2/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 542.7025 - root_mean_squared_error: 22.5851 - val_loss: 160.5796 - val_root_mean_squared_error: 12.6720
# Epoch 3/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 97.5796 - root_mean_squared_error: 9.8778 - val_loss: 149.8316 - val_root_mean_squared_error: 12.2406
# Epoch 4/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 93.1517 - root_mean_squared_error: 9.6511 - val_loss: 133.5087 - val_root_mean_squared_error: 11.5546
# Epoch 5/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 92.1383 - root_mean_squared_error: 9.5984 - val_loss: 136.9897 - val_root_mean_squared_error: 11.7043
# Epoch 6/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 91.7641 - root_mean_squared_error: 9.5792 - val_loss: 122.5798 - val_root_mean_squared_error: 11.0716
# Epoch 7/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 95.2133 - root_mean_squared_error: 9.7572 - val_loss: 229.1579 - val_root_mean_squared_error: 15.1380
# Epoch 8/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 100.5666 - root_mean_squared_error: 10.0256 - val_loss: 150.3616 - val_root_mean_squared_error: 12.2622
# Epoch 9/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 104.0590 - root_mean_squared_error: 10.2000 - val_loss: 162.1576 - val_root_mean_squared_error: 12.7341
# Epoch 10/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 104.6027 - root_mean_squared_error: 10.2220 - val_loss: 94.8502 - val_root_mean_squared_error: 9.7391
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 84.6680 - root_mean_squared_error: 9.2007
# Epoch 1/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 464836.2500 - root_mean_squared_error: 594.3819 - val_loss: 135.9268 - val_root_mean_squared_error: 11.6588
# Epoch 2/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 103.2338 - root_mean_squared_error: 10.1579 - val_loss: 113.0246 - val_root_mean_squared_error: 10.6313
# Epoch 3/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 99.2807 - root_mean_squared_error: 9.9632 - val_loss: 128.8844 - val_root_mean_squared_error: 11.3527
# Epoch 4/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 105.3479 - root_mean_squared_error: 10.2629 - val_loss: 91.9682 - val_root_mean_squared_error: 9.5900
# Epoch 5/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 118.7641 - root_mean_squared_error: 10.8917 - val_loss: 156.9758 - val_root_mean_squared_error: 12.5290
# Epoch 6/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 113.3710 - root_mean_squared_error: 10.6331 - val_loss: 82.2877 - val_root_mean_squared_error: 9.0713
# Epoch 7/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 102.0439 - root_mean_squared_error: 10.1009 - val_loss: 96.6717 - val_root_mean_squared_error: 9.8322
# Epoch 8/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 97.3196 - root_mean_squared_error: 9.8641 - val_loss: 80.5840 - val_root_mean_squared_error: 8.9769
# Epoch 9/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 96.4829 - root_mean_squared_error: 9.8216 - val_loss: 87.6141 - val_root_mean_squared_error: 9.3602
# Epoch 10/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 89.2078 - root_mean_squared_error: 9.4429 - val_loss: 96.7389 - val_root_mean_squared_error: 9.8356
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 93.3411 - root_mean_squared_error: 9.6583
# Epoch 1/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 679157.8125 - root_mean_squared_error: 738.8583 - val_loss: 760.8987 - val_root_mean_squared_error: 27.5844
# Epoch 2/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 262.0922 - root_mean_squared_error: 15.8863 - val_loss: 149.5087 - val_root_mean_squared_error: 12.2274
# Epoch 3/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 98.6730 - root_mean_squared_error: 9.9331 - val_loss: 138.5651 - val_root_mean_squared_error: 11.7714
# Epoch 4/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 93.5987 - root_mean_squared_error: 9.6742 - val_loss: 127.4478 - val_root_mean_squared_error: 11.2893
# Epoch 5/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 92.2398 - root_mean_squared_error: 9.6038 - val_loss: 142.4322 - val_root_mean_squared_error: 11.9345
# Epoch 6/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 94.0402 - root_mean_squared_error: 9.6970 - val_loss: 122.5648 - val_root_mean_squared_error: 11.0709
# Epoch 7/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 100.5906 - root_mean_squared_error: 10.0281 - val_loss: 112.6385 - val_root_mean_squared_error: 10.6131
# Epoch 8/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 99.6008 - root_mean_squared_error: 9.9766 - val_loss: 118.7827 - val_root_mean_squared_error: 10.8987
# Epoch 9/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 99.4926 - root_mean_squared_error: 9.9731 - val_loss: 98.5774 - val_root_mean_squared_error: 9.9286
# Epoch 10/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 103.0205 - root_mean_squared_error: 10.1480 - val_loss: 92.9582 - val_root_mean_squared_error: 9.6415
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 84.5077 - root_mean_squared_error: 9.1909
# Epoch 1/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 4003965.5000 - root_mean_squared_error: 2000.9908 - val_loss: 3963313.2500 - val_root_mean_squared_error: 1990.8071
# Epoch 2/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 3158903.5000 - root_mean_squared_error: 1762.1154 - val_loss: 185558.9375 - val_root_mean_squared_error: 430.7655
# Epoch 3/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 176954.5625 - root_mean_squared_error: 420.1536 - val_loss: 166055.7344 - val_root_mean_squared_error: 407.4994
# Epoch 4/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 156432.0938 - root_mean_squared_error: 395.0273 - val_loss: 153490.5156 - val_root_mean_squared_error: 391.7787
# Epoch 5/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 133126.3438 - root_mean_squared_error: 364.7755 - val_loss: 142826.2812 - val_root_mean_squared_error: 377.9236
# Epoch 6/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 132361.2812 - root_mean_squared_error: 363.6453 - val_loss: 133310.1875 - val_root_mean_squared_error: 365.1167
# Epoch 7/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 129007.2266 - root_mean_squared_error: 358.8907 - val_loss: 124692.1641 - val_root_mean_squared_error: 353.1178
# Epoch 8/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 116224.2266 - root_mean_squared_error: 340.8108 - val_loss: 116918.2188 - val_root_mean_squared_error: 341.9331
# Epoch 9/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 113228.0625 - root_mean_squared_error: 336.3116 - val_loss: 109804.4688 - val_root_mean_squared_error: 331.3676
# Epoch 10/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 100869.0312 - root_mean_squared_error: 317.5277 - val_loss: 103232.1719 - val_root_mean_squared_error: 321.2976
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 90998.3281 - root_mean_squared_error: 301.5201
# Epoch 1/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 4006975.2500 - root_mean_squared_error: 2001.7430 - val_loss: 3999566.0000 - val_root_mean_squared_error: 1999.8915
# Epoch 2/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 3990284.2500 - root_mean_squared_error: 1997.5688 - val_loss: 3905452.5000 - val_root_mean_squared_error: 1976.2218
# Epoch 3/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2809380.7500 - root_mean_squared_error: 1653.7648 - val_loss: 191986.6250 - val_root_mean_squared_error: 438.1628
# Epoch 4/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 165450.1406 - root_mean_squared_error: 406.6579 - val_loss: 171361.9844 - val_root_mean_squared_error: 413.9589
# Epoch 5/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 155297.4062 - root_mean_squared_error: 393.9583 - val_loss: 161837.3438 - val_root_mean_squared_error: 402.2901
# Epoch 6/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 150587.4375 - root_mean_squared_error: 387.8549 - val_loss: 154534.8906 - val_root_mean_squared_error: 393.1093
# Epoch 7/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 144467.1875 - root_mean_squared_error: 379.9645 - val_loss: 148050.8438 - val_root_mean_squared_error: 384.7737
# Epoch 8/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 142793.9844 - root_mean_squared_error: 377.7713 - val_loss: 142231.9375 - val_root_mean_squared_error: 377.1365
# Epoch 9/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 128383.2188 - root_mean_squared_error: 358.2245 - val_loss: 136891.7188 - val_root_mean_squared_error: 369.9888
# Epoch 10/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 118686.6797 - root_mean_squared_error: 344.4343 - val_loss: 131722.4688 - val_root_mean_squared_error: 362.9359
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 117563.2031 - root_mean_squared_error: 342.6305
# Epoch 1/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 4005546.7500 - root_mean_squared_error: 2001.3860 - val_loss: 3957377.2500 - val_root_mean_squared_error: 1989.3158
# Epoch 2/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 2911716.7500 - root_mean_squared_error: 1684.6844 - val_loss: 192194.3438 - val_root_mean_squared_error: 438.3997
# Epoch 3/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 179230.5625 - root_mean_squared_error: 423.2331 - val_loss: 168622.0469 - val_root_mean_squared_error: 410.6361
# Epoch 4/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 157563.6406 - root_mean_squared_error: 396.8016 - val_loss: 152724.0781 - val_root_mean_squared_error: 390.7993
# Epoch 5/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 148200.5938 - root_mean_squared_error: 384.8776 - val_loss: 139959.8750 - val_root_mean_squared_error: 374.1121
# Epoch 6/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 136988.9844 - root_mean_squared_error: 369.9629 - val_loss: 128684.0469 - val_root_mean_squared_error: 358.7256
# Epoch 7/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 118579.0469 - root_mean_squared_error: 344.3084 - val_loss: 118711.7500 - val_root_mean_squared_error: 344.5457
# Epoch 8/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 108702.2500 - root_mean_squared_error: 329.5666 - val_loss: 109947.0625 - val_root_mean_squared_error: 331.5827
# Epoch 9/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 108796.8516 - root_mean_squared_error: 329.6062 - val_loss: 102126.3203 - val_root_mean_squared_error: 319.5721
# Epoch 10/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 96464.6328 - root_mean_squared_error: 310.4788 - val_loss: 95152.1484 - val_root_mean_squared_error: 308.4674
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 84750.8750 - root_mean_squared_error: 290.9116
# Epoch 1/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 4006181.5000 - root_mean_squared_error: 2001.5447 - val_loss: 3996903.7500 - val_root_mean_squared_error: 1999.2258
# Epoch 2/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 3984360.7500 - root_mean_squared_error: 1996.0845 - val_loss: 3686938.0000 - val_root_mean_squared_error: 1920.1401
# Epoch 3/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1407929.6250 - root_mean_squared_error: 1131.2019 - val_loss: 179182.0781 - val_root_mean_squared_error: 423.2990
# Epoch 4/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 169495.5938 - root_mean_squared_error: 411.5923 - val_loss: 163371.3438 - val_root_mean_squared_error: 404.1922
# Epoch 5/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 145080.8125 - root_mean_squared_error: 380.7335 - val_loss: 153203.7344 - val_root_mean_squared_error: 391.4125
# Epoch 6/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 131513.4844 - root_mean_squared_error: 362.4427 - val_loss: 144950.4531 - val_root_mean_squared_error: 380.7236
# Epoch 7/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 137802.4062 - root_mean_squared_error: 371.1625 - val_loss: 138296.6250 - val_root_mean_squared_error: 371.8825
# Epoch 8/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 131433.0000 - root_mean_squared_error: 362.3451 - val_loss: 131909.6406 - val_root_mean_squared_error: 363.1937
# Epoch 9/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 118416.0703 - root_mean_squared_error: 344.0339 - val_loss: 126114.7031 - val_root_mean_squared_error: 355.1263
# Epoch 10/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 125545.6484 - root_mean_squared_error: 353.6263 - val_loss: 120658.0312 - val_root_mean_squared_error: 347.3586
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 104954.3984 - root_mean_squared_error: 323.7491
# Epoch 1/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 730588.6875 - root_mean_squared_error: 777.3685 - val_loss: 30049.6426 - val_root_mean_squared_error: 173.3483
# Epoch 2/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 16210.5840 - root_mean_squared_error: 125.9846 - val_loss: 852.8839 - val_root_mean_squared_error: 29.2042
# Epoch 3/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 293.1978 - root_mean_squared_error: 16.8066 - val_loss: 122.7790 - val_root_mean_squared_error: 11.0806
# Epoch 4/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 104.4991 - root_mean_squared_error: 10.2219 - val_loss: 142.7138 - val_root_mean_squared_error: 11.9463
# Epoch 5/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 104.0444 - root_mean_squared_error: 10.1996 - val_loss: 102.9958 - val_root_mean_squared_error: 10.1487
# Epoch 6/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 97.4881 - root_mean_squared_error: 9.8723 - val_loss: 88.4463 - val_root_mean_squared_error: 9.4046
# Epoch 7/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 96.6625 - root_mean_squared_error: 9.8306 - val_loss: 82.0681 - val_root_mean_squared_error: 9.0591
# Epoch 8/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 92.7743 - root_mean_squared_error: 9.6315 - val_loss: 88.2095 - val_root_mean_squared_error: 9.3920
# Epoch 9/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 90.3180 - root_mean_squared_error: 9.5026 - val_loss: 115.2900 - val_root_mean_squared_error: 10.7373
# Epoch 10/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 85.8593 - root_mean_squared_error: 9.2655 - val_loss: 94.4211 - val_root_mean_squared_error: 9.7171
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 90.9594 - root_mean_squared_error: 9.5368
# Epoch 1/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 1093816.7500 - root_mean_squared_error: 971.3044 - val_loss: 58202.9727 - val_root_mean_squared_error: 241.2529
# Epoch 2/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 40060.6641 - root_mean_squared_error: 199.4804 - val_loss: 12737.5293 - val_root_mean_squared_error: 112.8607
# Epoch 3/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6632.9243 - root_mean_squared_error: 80.4205 - val_loss: 371.4434 - val_root_mean_squared_error: 19.2729
# Epoch 4/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 161.8333 - root_mean_squared_error: 12.7029 - val_loss: 174.1921 - val_root_mean_squared_error: 13.1982
# Epoch 5/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 106.6534 - root_mean_squared_error: 10.3248 - val_loss: 143.4232 - val_root_mean_squared_error: 11.9759
# Epoch 6/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 101.4824 - root_mean_squared_error: 10.0722 - val_loss: 160.9594 - val_root_mean_squared_error: 12.6870
# Epoch 7/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 97.4733 - root_mean_squared_error: 9.8723 - val_loss: 125.0004 - val_root_mean_squared_error: 11.1804
# Epoch 8/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 96.1898 - root_mean_squared_error: 9.8060 - val_loss: 158.3265 - val_root_mean_squared_error: 12.5828
# Epoch 9/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 97.9702 - root_mean_squared_error: 9.8971 - val_loss: 100.3995 - val_root_mean_squared_error: 10.0200
# Epoch 10/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 94.3416 - root_mean_squared_error: 9.7111 - val_loss: 104.2600 - val_root_mean_squared_error: 10.2108
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 91.2011 - root_mean_squared_error: 9.5483
# Epoch 1/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 670597.0000 - root_mean_squared_error: 736.0539 - val_loss: 10443.7939 - val_root_mean_squared_error: 102.1949
# Epoch 2/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 3831.9927 - root_mean_squared_error: 59.9111 - val_loss: 168.4561 - val_root_mean_squared_error: 12.9791
# Epoch 3/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 112.0030 - root_mean_squared_error: 10.5826 - val_loss: 146.5472 - val_root_mean_squared_error: 12.1057
# Epoch 4/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 108.0198 - root_mean_squared_error: 10.3905 - val_loss: 109.4868 - val_root_mean_squared_error: 10.4636
# Epoch 5/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 100.8575 - root_mean_squared_error: 10.0420 - val_loss: 102.8858 - val_root_mean_squared_error: 10.1433
# Epoch 6/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 93.1531 - root_mean_squared_error: 9.6493 - val_loss: 129.0120 - val_root_mean_squared_error: 11.3583
# Epoch 7/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 95.0384 - root_mean_squared_error: 9.7469 - val_loss: 91.8544 - val_root_mean_squared_error: 9.5841
# Epoch 8/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 92.7330 - root_mean_squared_error: 9.6285 - val_loss: 96.0968 - val_root_mean_squared_error: 9.8029
# Epoch 9/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 89.4375 - root_mean_squared_error: 9.4536 - val_loss: 102.0481 - val_root_mean_squared_error: 10.1019
# Epoch 10/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 85.0911 - root_mean_squared_error: 9.2236 - val_loss: 86.7220 - val_root_mean_squared_error: 9.3125
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 84.0469 - root_mean_squared_error: 9.1654
# Epoch 1/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1056067.0000 - root_mean_squared_error: 954.1232 - val_loss: 58653.7969 - val_root_mean_squared_error: 242.1855
# Epoch 2/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 40456.1875 - root_mean_squared_error: 200.2583 - val_loss: 12372.4141 - val_root_mean_squared_error: 111.2314
# Epoch 3/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 7010.6973 - root_mean_squared_error: 82.3096 - val_loss: 423.3247 - val_root_mean_squared_error: 20.5749
# Epoch 4/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 171.6556 - root_mean_squared_error: 13.0814 - val_loss: 216.8347 - val_root_mean_squared_error: 14.7253
# Epoch 5/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 108.8322 - root_mean_squared_error: 10.4227 - val_loss: 158.4491 - val_root_mean_squared_error: 12.5877
# Epoch 6/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 99.2373 - root_mean_squared_error: 9.9609 - val_loss: 129.6100 - val_root_mean_squared_error: 11.3846
# Epoch 7/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 96.9492 - root_mean_squared_error: 9.8455 - val_loss: 141.8839 - val_root_mean_squared_error: 11.9115
# Epoch 8/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 99.1387 - root_mean_squared_error: 9.9552 - val_loss: 123.3528 - val_root_mean_squared_error: 11.1064
# Epoch 9/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 95.1870 - root_mean_squared_error: 9.7551 - val_loss: 111.6430 - val_root_mean_squared_error: 10.5661
# Epoch 10/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 91.7964 - root_mean_squared_error: 9.5804 - val_loss: 127.8224 - val_root_mean_squared_error: 11.3059
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 104.2732 - root_mean_squared_error: 10.2093

# %%
# Flatten the list of tuples
flattened_data = [item for sublist in resultado for item in sublist]

# Convert the flattened data into a DataFrame
df = pd.DataFrame(flattened_data, columns=['Epocas', 'Modelo', 'RMSE', 'Learning rate'])

# Order the DataFrame by the third position (Value3) in ascending order
df_sorted = df.sort_values(by='RMSE', ascending=True)

df_sorted.head(10)
# Out:
#     Epocas    Modelo        RMSE  Learning rate
# 0       50      Adam    8.935256             32
# 10     100    Adamax    9.316666             32
# 1       50      Adam    9.320942             64
# 3      100      Adam    9.358819             64
# 8       50    Adamax    9.643458             32
# 9       50    Adamax    9.710032             64
# 2      100      Adam    9.784650             32
# 11     100    Adamax   10.365621             64
# 6      100  Adadelta  295.531036             32
# 4       50  Adadelta  306.130829             32

# %%
resultado_adam_opt = list()

epocas = [50, 100]
batch_size = [16,32,64]
learning_rates = [0.001,0.005,0.009,0.01, 0.05, 0.09, 0.1, 0.5, 0.9]

for e in epocas:
    for b in batch_size:
        for l in learning_rates:
                ret = OptimizedModelAdam(e, b, X_train_scaled, y_train, X_val_scaled, y_val, l)
                resultado_adam_opt.append([ret])
# Out:
# Epoch 1/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 297773.0938 - root_mean_squared_error: 460.7488 - val_loss: 104.3359 - val_root_mean_squared_error: 10.2145
# Epoch 2/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 108.0031 - root_mean_squared_error: 10.3906 - val_loss: 116.2921 - val_root_mean_squared_error: 10.7839
# Epoch 3/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 123.1659 - root_mean_squared_error: 11.0963 - val_loss: 119.7344 - val_root_mean_squared_error: 10.9423
# Epoch 4/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 118.9674 - root_mean_squared_error: 10.9047 - val_loss: 102.0721 - val_root_mean_squared_error: 10.1031
# Epoch 5/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 117.7859 - root_mean_squared_error: 10.8519 - val_loss: 92.1441 - val_root_mean_squared_error: 9.5992
# Epoch 6/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 108.9500 - root_mean_squared_error: 10.4346 - val_loss: 115.5125 - val_root_mean_squared_error: 10.7477
# Epoch 7/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 111.4995 - root_mean_squared_error: 10.5580 - val_loss: 275.1060 - val_root_mean_squared_error: 16.5863
# Epoch 8/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 103.4652 - root_mean_squared_error: 10.1682 - val_loss: 176.7786 - val_root_mean_squared_error: 13.2958
# Epoch 9/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 102.0639 - root_mean_squared_error: 10.1005 - val_loss: 96.2464 - val_root_mean_squared_error: 9.8105
# Epoch 10/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 105.1331 - root_mean_squared_error: 10.2496 - val_loss: 96.6710 - val_root_mean_squared_error: 9.8321
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 97.7754 - root_mean_squared_error: 9.8805
# Epoch 1/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 137219.8125 - root_mean_squared_error: 297.8240 - val_loss: 246.3836 - val_root_mean_squared_error: 15.6966
# Epoch 2/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 180.9176 - root_mean_squared_error: 13.4412 - val_loss: 141.2295 - val_root_mean_squared_error: 11.8840
# Epoch 3/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 224.4908 - root_mean_squared_error: 14.9774 - val_loss: 114.3217 - val_root_mean_squared_error: 10.6921
# Epoch 4/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 220.9227 - root_mean_squared_error: 14.8523 - val_loss: 252.0315 - val_root_mean_squared_error: 15.8755
# Epoch 5/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 247.1775 - root_mean_squared_error: 15.6929 - val_loss: 93.5020 - val_root_mean_squared_error: 9.6696
# Epoch 6/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 221.9517 - root_mean_squared_error: 14.8807 - val_loss: 187.0798 - val_root_mean_squared_error: 13.6777
# Epoch 7/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 341.8880 - root_mean_squared_error: 18.2511 - val_loss: 286.7269 - val_root_mean_squared_error: 16.9330
# Epoch 8/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 211.7661 - root_mean_squared_error: 14.5365 - val_loss: 156.6035 - val_root_mean_squared_error: 12.5141
# Epoch 9/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 189.2978 - root_mean_squared_error: 13.7542 - val_loss: 120.3541 - val_root_mean_squared_error: 10.9706
# Epoch 10/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 189.1870 - root_mean_squared_error: 13.7396 - val_loss: 139.6841 - val_root_mean_squared_error: 11.8188
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 137.4539 - root_mean_squared_error: 11.7217
# Epoch 1/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 81726.6641 - root_mean_squared_error: 221.0045 - val_loss: 353.3065 - val_root_mean_squared_error: 18.7964
# Epoch 2/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 329.0491 - root_mean_squared_error: 18.1223 - val_loss: 266.2390 - val_root_mean_squared_error: 16.3168
# Epoch 3/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 343.7226 - root_mean_squared_error: 18.5060 - val_loss: 114.3784 - val_root_mean_squared_error: 10.6948
# Epoch 4/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 402.4582 - root_mean_squared_error: 20.0427 - val_loss: 196.8110 - val_root_mean_squared_error: 14.0289
# Epoch 5/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 296.4418 - root_mean_squared_error: 17.2100 - val_loss: 189.3316 - val_root_mean_squared_error: 13.7598
# Epoch 6/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 301.6294 - root_mean_squared_error: 17.3572 - val_loss: 122.9528 - val_root_mean_squared_error: 11.0884
# Epoch 7/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 279.6161 - root_mean_squared_error: 16.7139 - val_loss: 347.1585 - val_root_mean_squared_error: 18.6322
# Epoch 8/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 260.7062 - root_mean_squared_error: 16.1246 - val_loss: 244.8265 - val_root_mean_squared_error: 15.6469
# Epoch 9/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 233.0074 - root_mean_squared_error: 15.2587 - val_loss: 118.1045 - val_root_mean_squared_error: 10.8676
# Epoch 10/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 242.9382 - root_mean_squared_error: 15.5759 - val_loss: 114.9114 - val_root_mean_squared_error: 10.7197
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 112.0888 - root_mean_squared_error: 10.5860
# Epoch 1/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - loss: 109420.7500 - root_mean_squared_error: 261.5383 - val_loss: 147.0873 - val_root_mean_squared_error: 12.1280
# Epoch 2/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 225.2825 - root_mean_squared_error: 14.9761 - val_loss: 1091.8740 - val_root_mean_squared_error: 33.0435
# Epoch 3/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 331.2307 - root_mean_squared_error: 18.1754 - val_loss: 641.8071 - val_root_mean_squared_error: 25.3339
# Epoch 4/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 389.6696 - root_mean_squared_error: 19.7135 - val_loss: 200.2771 - val_root_mean_squared_error: 14.1519
# Epoch 5/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 305.7097 - root_mean_squared_error: 17.4666 - val_loss: 277.5797 - val_root_mean_squared_error: 16.6607
# Epoch 6/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 308.7816 - root_mean_squared_error: 17.5700 - val_loss: 202.5380 - val_root_mean_squared_error: 14.2316
# Epoch 7/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 285.3031 - root_mean_squared_error: 16.8702 - val_loss: 245.1185 - val_root_mean_squared_error: 15.6563
# Epoch 8/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 262.1769 - root_mean_squared_error: 16.1843 - val_loss: 127.4981 - val_root_mean_squared_error: 11.2915
# Epoch 9/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 308.2752 - root_mean_squared_error: 17.5406 - val_loss: 132.5805 - val_root_mean_squared_error: 11.5144
# Epoch 10/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 243.4308 - root_mean_squared_error: 15.5896 - val_loss: 239.6174 - val_root_mean_squared_error: 15.4796
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 237.8103 - root_mean_squared_error: 15.4193
# Epoch 1/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 188603.2812 - root_mean_squared_error: 334.1230 - val_loss: 1167.6792 - val_root_mean_squared_error: 34.1713
# Epoch 2/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 769.0201 - root_mean_squared_error: 27.6964 - val_loss: 112.7825 - val_root_mean_squared_error: 10.6199
# Epoch 3/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 550.3337 - root_mean_squared_error: 23.3860 - val_loss: 1023.4290 - val_root_mean_squared_error: 31.9911
# Epoch 4/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 457.9579 - root_mean_squared_error: 21.3872 - val_loss: 132.4317 - val_root_mean_squared_error: 11.5079
# Epoch 5/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 378.1578 - root_mean_squared_error: 19.4263 - val_loss: 182.8555 - val_root_mean_squared_error: 13.5224
# Epoch 6/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 329.6100 - root_mean_squared_error: 18.1494 - val_loss: 292.0072 - val_root_mean_squared_error: 17.0882
# Epoch 7/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 298.9162 - root_mean_squared_error: 17.2810 - val_loss: 226.0054 - val_root_mean_squared_error: 15.0335
# Epoch 8/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 300.9938 - root_mean_squared_error: 17.3203 - val_loss: 382.9802 - val_root_mean_squared_error: 19.5699
# Epoch 9/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 263.3937 - root_mean_squared_error: 16.2207 - val_loss: 392.8463 - val_root_mean_squared_error: 19.8204
# Epoch 10/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 278.8062 - root_mean_squared_error: 16.6915 - val_loss: 116.7214 - val_root_mean_squared_error: 10.8038
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 113.8247 - root_mean_squared_error: 10.6678
# Epoch 1/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - loss: 14592757.0000 - root_mean_squared_error: 2807.2295 - val_loss: 5570.8667 - val_root_mean_squared_error: 74.6382
# Epoch 2/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 6858.7666 - root_mean_squared_error: 72.9393 - val_loss: 1246.1263 - val_root_mean_squared_error: 35.3005
# Epoch 3/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 1728.0553 - root_mean_squared_error: 39.3970 - val_loss: 141.4698 - val_root_mean_squared_error: 11.8941
# Epoch 4/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 291.5055 - root_mean_squared_error: 15.6540 - val_loss: 172.9319 - val_root_mean_squared_error: 13.1504
# Epoch 5/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 246.5466 - root_mean_squared_error: 15.5937 - val_loss: 772.8135 - val_root_mean_squared_error: 27.7995
# Epoch 6/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 549.0007 - root_mean_squared_error: 23.3947 - val_loss: 377.8883 - val_root_mean_squared_error: 19.4394
# Epoch 7/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 651.6945 - root_mean_squared_error: 24.9987 - val_loss: 115.0287 - val_root_mean_squared_error: 10.7251
# Epoch 8/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 428.6468 - root_mean_squared_error: 20.6849 - val_loss: 308.8778 - val_root_mean_squared_error: 17.5749
# Epoch 9/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 704.4918 - root_mean_squared_error: 26.0929 - val_loss: 114.8464 - val_root_mean_squared_error: 10.7166
# Epoch 10/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 4116953.7500 - root_mean_squared_error: 1231.6637 - val_loss: 8456.3281 - val_root_mean_squared_error: 91.9583
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8445.7031 - root_mean_squared_error: 91.9004
# Epoch 1/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - loss: 21090414.0000 - root_mean_squared_error: 3347.7068 - val_loss: 263.3575 - val_root_mean_squared_error: 16.2283
# Epoch 2/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 242.3064 - root_mean_squared_error: 15.5471 - val_loss: 176.6957 - val_root_mean_squared_error: 13.2927
# Epoch 3/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 391.2427 - root_mean_squared_error: 19.7514 - val_loss: 423.1286 - val_root_mean_squared_error: 20.5701
# Epoch 4/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 569.0034 - root_mean_squared_error: 23.8229 - val_loss: 648.1507 - val_root_mean_squared_error: 25.4588
# Epoch 5/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 495.5071 - root_mean_squared_error: 22.2439 - val_loss: 252.6000 - val_root_mean_squared_error: 15.8934
# Epoch 6/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 9859.0303 - root_mean_squared_error: 92.0511 - val_loss: 308.1390 - val_root_mean_squared_error: 17.5539
# Epoch 7/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 500.0799 - root_mean_squared_error: 22.3020 - val_loss: 494.1053 - val_root_mean_squared_error: 22.2285
# Epoch 8/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 519.8011 - root_mean_squared_error: 22.7672 - val_loss: 155.8015 - val_root_mean_squared_error: 12.4820
# Epoch 9/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 439.3095 - root_mean_squared_error: 20.9160 - val_loss: 486.3376 - val_root_mean_squared_error: 22.0531
# Epoch 10/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 332.0675 - root_mean_squared_error: 18.2003 - val_loss: 686.7320 - val_root_mean_squared_error: 26.2056
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 681.9044 - root_mean_squared_error: 26.1131
# Epoch 1/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 10530766979072.0000 - root_mean_squared_error: 2397936.7500 - val_loss: 114.7657 - val_root_mean_squared_error: 10.7129
# Epoch 2/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 33825.2188 - root_mean_squared_error: 91.3335 - val_loss: 114.6273 - val_root_mean_squared_error: 10.7064
# Epoch 3/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 127.9315 - root_mean_squared_error: 11.3095 - val_loss: 198.0536 - val_root_mean_squared_error: 14.0732
# Epoch 4/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 156.5357 - root_mean_squared_error: 12.5013 - val_loss: 606.8353 - val_root_mean_squared_error: 24.6340
# Epoch 5/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 323.0666 - root_mean_squared_error: 17.9452 - val_loss: 333.2347 - val_root_mean_squared_error: 18.2547
# Epoch 6/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 362.0859 - root_mean_squared_error: 19.0118 - val_loss: 305.0568 - val_root_mean_squared_error: 17.4659
# Epoch 7/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 314.0144 - root_mean_squared_error: 17.6972 - val_loss: 577.3805 - val_root_mean_squared_error: 24.0287
# Epoch 8/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 272.8743 - root_mean_squared_error: 16.5023 - val_loss: 128.0661 - val_root_mean_squared_error: 11.3166
# Epoch 9/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 275.6815 - root_mean_squared_error: 16.5904 - val_loss: 163.4613 - val_root_mean_squared_error: 12.7852
# Epoch 10/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 233.5403 - root_mean_squared_error: 15.2796 - val_loss: 114.6016 - val_root_mean_squared_error: 10.7052
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 111.8093 - root_mean_squared_error: 10.5727
# Epoch 1/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 2682509066240000.0000 - root_mean_squared_error: 37733936.0000 - val_loss: 3845888.5000 - val_root_mean_squared_error: 1961.0938
# Epoch 2/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 3829776.0000 - root_mean_squared_error: 1956.9794 - val_loss: 3742403.0000 - val_root_mean_squared_error: 1934.5292
# Epoch 3/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 3663765.7500 - root_mean_squared_error: 1914.0446 - val_loss: 3243462.7500 - val_root_mean_squared_error: 1800.9617
# Epoch 4/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2922523.2500 - root_mean_squared_error: 1708.4132 - val_loss: 1534358.0000 - val_root_mean_squared_error: 1238.6920
# Epoch 5/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 999755.6875 - root_mean_squared_error: 989.7795 - val_loss: 30405.1289 - val_root_mean_squared_error: 174.3707
# Epoch 6/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 9333.6426 - root_mean_squared_error: 91.4051 - val_loss: 114.6041 - val_root_mean_squared_error: 10.7053
# Epoch 7/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 117.9499 - root_mean_squared_error: 10.8594 - val_loss: 114.8333 - val_root_mean_squared_error: 10.7160
# Epoch 8/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 118.7751 - root_mean_squared_error: 10.8977 - val_loss: 114.5653 - val_root_mean_squared_error: 10.7035
# Epoch 9/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 116.8132 - root_mean_squared_error: 10.8074 - val_loss: 115.6299 - val_root_mean_squared_error: 10.7531
# Epoch 10/50
# 3306/3306 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 121.6424 - root_mean_squared_error: 11.0283 - val_loss: 114.6010 - val_root_mean_squared_error: 10.7052
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 111.8087 - root_mean_squared_error: 10.5726
# Epoch 1/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 425822.3750 - root_mean_squared_error: 563.6840 - val_loss: 127.7805 - val_root_mean_squared_error: 11.3040
# Epoch 2/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 99.5614 - root_mean_squared_error: 9.9776 - val_loss: 111.1878 - val_root_mean_squared_error: 10.5446
# Epoch 3/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 95.8627 - root_mean_squared_error: 9.7904 - val_loss: 103.4265 - val_root_mean_squared_error: 10.1699
# Epoch 4/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 103.5874 - root_mean_squared_error: 10.1748 - val_loss: 107.0689 - val_root_mean_squared_error: 10.3474
# Epoch 5/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 107.6769 - root_mean_squared_error: 10.3748 - val_loss: 83.5134 - val_root_mean_squared_error: 9.1386
# Epoch 6/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 110.7967 - root_mean_squared_error: 10.5212 - val_loss: 138.8176 - val_root_mean_squared_error: 11.7821
# Epoch 7/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 99.2186 - root_mean_squared_error: 9.9558 - val_loss: 161.6518 - val_root_mean_squared_error: 12.7142
# Epoch 8/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 102.0414 - root_mean_squared_error: 10.1004 - val_loss: 89.2049 - val_root_mean_squared_error: 9.4448
# Epoch 9/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 97.0728 - root_mean_squared_error: 9.8517 - val_loss: 110.6148 - val_root_mean_squared_error: 10.5174
# Epoch 10/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 97.0055 - root_mean_squared_error: 9.8421 - val_loss: 139.9591 - val_root_mean_squared_error: 11.8304
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 135.9341 - root_mean_squared_error: 11.6572
# Epoch 1/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 179723.6250 - root_mean_squared_error: 345.3548 - val_loss: 100.9102 - val_root_mean_squared_error: 10.0454
# Epoch 2/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 104.5074 - root_mean_squared_error: 10.2203 - val_loss: 91.4786 - val_root_mean_squared_error: 9.5644
# Epoch 3/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 142.0143 - root_mean_squared_error: 11.9018 - val_loss: 259.3958 - val_root_mean_squared_error: 16.1058
# Epoch 4/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 185.2049 - root_mean_squared_error: 13.5856 - val_loss: 276.8987 - val_root_mean_squared_error: 16.6403
# Epoch 5/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 189.8391 - root_mean_squared_error: 13.7708 - val_loss: 208.9088 - val_root_mean_squared_error: 14.4537
# Epoch 6/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 208.2039 - root_mean_squared_error: 14.4096 - val_loss: 86.8677 - val_root_mean_squared_error: 9.3203
# Epoch 7/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 199.4946 - root_mean_squared_error: 14.1079 - val_loss: 162.2382 - val_root_mean_squared_error: 12.7373
# Epoch 8/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 218.9539 - root_mean_squared_error: 14.7856 - val_loss: 242.5524 - val_root_mean_squared_error: 15.5741
# Epoch 9/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 215.9849 - root_mean_squared_error: 14.6899 - val_loss: 93.3299 - val_root_mean_squared_error: 9.6607
# Epoch 10/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 195.0796 - root_mean_squared_error: 13.9492 - val_loss: 167.3847 - val_root_mean_squared_error: 12.9377
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 161.7863 - root_mean_squared_error: 12.7190
# Epoch 1/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 140032.3594 - root_mean_squared_error: 299.5099 - val_loss: 111.9672 - val_root_mean_squared_error: 10.5815
# Epoch 2/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 139.1622 - root_mean_squared_error: 11.7920 - val_loss: 197.3088 - val_root_mean_squared_error: 14.0467
# Epoch 3/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 203.7173 - root_mean_squared_error: 14.2405 - val_loss: 173.4551 - val_root_mean_squared_error: 13.1702
# Epoch 4/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 287.4113 - root_mean_squared_error: 16.9367 - val_loss: 428.1115 - val_root_mean_squared_error: 20.6909
# Epoch 5/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 297.1366 - root_mean_squared_error: 17.2233 - val_loss: 154.2462 - val_root_mean_squared_error: 12.4196
# Epoch 6/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 257.6910 - root_mean_squared_error: 16.0286 - val_loss: 138.9747 - val_root_mean_squared_error: 11.7888
# Epoch 7/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 318.3521 - root_mean_squared_error: 17.8078 - val_loss: 165.2112 - val_root_mean_squared_error: 12.8535
# Epoch 8/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 295.1759 - root_mean_squared_error: 17.1606 - val_loss: 206.3773 - val_root_mean_squared_error: 14.3658
# Epoch 9/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 287.0452 - root_mean_squared_error: 16.8985 - val_loss: 106.0778 - val_root_mean_squared_error: 10.2994
# Epoch 10/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 237.7890 - root_mean_squared_error: 15.4068 - val_loss: 113.3036 - val_root_mean_squared_error: 10.6444
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 111.3362 - root_mean_squared_error: 10.5496
# Epoch 1/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 97712.5391 - root_mean_squared_error: 242.8020 - val_loss: 314.7402 - val_root_mean_squared_error: 17.7409
# Epoch 2/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 243.0412 - root_mean_squared_error: 15.5428 - val_loss: 106.8390 - val_root_mean_squared_error: 10.3363
# Epoch 3/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 396.2684 - root_mean_squared_error: 19.8844 - val_loss: 167.7183 - val_root_mean_squared_error: 12.9506
# Epoch 4/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 335.0139 - root_mean_squared_error: 18.2702 - val_loss: 263.8585 - val_root_mean_squared_error: 16.2437
# Epoch 5/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 311.1765 - root_mean_squared_error: 17.6282 - val_loss: 125.9323 - val_root_mean_squared_error: 11.2220
# Epoch 6/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 295.8684 - root_mean_squared_error: 17.1484 - val_loss: 132.6315 - val_root_mean_squared_error: 11.5166
# Epoch 7/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 315.5609 - root_mean_squared_error: 17.7349 - val_loss: 372.4128 - val_root_mean_squared_error: 19.2980
# Epoch 8/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 284.5609 - root_mean_squared_error: 16.8554 - val_loss: 105.3590 - val_root_mean_squared_error: 10.2645
# Epoch 9/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 268.4874 - root_mean_squared_error: 16.3795 - val_loss: 251.1483 - val_root_mean_squared_error: 15.8477
# Epoch 10/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 290.7840 - root_mean_squared_error: 17.0152 - val_loss: 112.5596 - val_root_mean_squared_error: 10.6094
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 110.4644 - root_mean_squared_error: 10.5077
# Epoch 1/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 251580.6406 - root_mean_squared_error: 390.5407 - val_loss: 952.4297 - val_root_mean_squared_error: 30.8615
# Epoch 2/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 860.4557 - root_mean_squared_error: 29.2661 - val_loss: 2484.5759 - val_root_mean_squared_error: 49.8455
# Epoch 3/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 993.3297 - root_mean_squared_error: 31.4759 - val_loss: 859.1110 - val_root_mean_squared_error: 29.3106
# Epoch 4/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 758.1306 - root_mean_squared_error: 27.4552 - val_loss: 1260.1748 - val_root_mean_squared_error: 35.4989
# Epoch 5/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 609.4907 - root_mean_squared_error: 24.6522 - val_loss: 721.3338 - val_root_mean_squared_error: 26.8577
# Epoch 6/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 476.8267 - root_mean_squared_error: 21.7878 - val_loss: 195.6509 - val_root_mean_squared_error: 13.9875
# Epoch 7/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 451.3330 - root_mean_squared_error: 21.1652 - val_loss: 1128.3109 - val_root_mean_squared_error: 33.5903
# Epoch 8/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 388.3450 - root_mean_squared_error: 19.6623 - val_loss: 461.4372 - val_root_mean_squared_error: 21.4811
# Epoch 9/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 326.9467 - root_mean_squared_error: 18.0687 - val_loss: 387.3255 - val_root_mean_squared_error: 19.6806
# Epoch 10/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 371.5504 - root_mean_squared_error: 19.1161 - val_loss: 625.2208 - val_root_mean_squared_error: 25.0044
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 620.5073 - root_mean_squared_error: 24.9098
# Epoch 1/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 357570.6250 - root_mean_squared_error: 503.8957 - val_loss: 713.7236 - val_root_mean_squared_error: 26.7156
# Epoch 2/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 463.6438 - root_mean_squared_error: 21.5033 - val_loss: 589.0101 - val_root_mean_squared_error: 24.2695
# Epoch 3/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 550.6600 - root_mean_squared_error: 23.4464 - val_loss: 6062.4844 - val_root_mean_squared_error: 77.8620
# Epoch 4/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 539.6820 - root_mean_squared_error: 22.9842 - val_loss: 169.8914 - val_root_mean_squared_error: 13.0342
# Epoch 5/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 347.0533 - root_mean_squared_error: 18.5826 - val_loss: 623.6321 - val_root_mean_squared_error: 24.9726
# Epoch 6/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 2958.5359 - root_mean_squared_error: 50.5822 - val_loss: 216.8897 - val_root_mean_squared_error: 14.7272
# Epoch 7/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 184.4755 - root_mean_squared_error: 13.5746 - val_loss: 290.3929 - val_root_mean_squared_error: 17.0409
# Epoch 8/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 325.5439 - root_mean_squared_error: 18.0222 - val_loss: 143.1168 - val_root_mean_squared_error: 11.9631
# Epoch 9/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 328.7595 - root_mean_squared_error: 18.1074 - val_loss: 132.3386 - val_root_mean_squared_error: 11.5039
# Epoch 10/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 307.6889 - root_mean_squared_error: 17.5270 - val_loss: 117.0520 - val_root_mean_squared_error: 10.8191
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 114.4193 - root_mean_squared_error: 10.6950
# Epoch 1/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 1444974.1250 - root_mean_squared_error: 1017.5585 - val_loss: 115.2561 - val_root_mean_squared_error: 10.7357
# Epoch 2/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 118.7167 - root_mean_squared_error: 10.8955 - val_loss: 114.5763 - val_root_mean_squared_error: 10.7040
# Epoch 3/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 119.4462 - root_mean_squared_error: 10.9273 - val_loss: 115.8008 - val_root_mean_squared_error: 10.7611
# Epoch 4/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 121.2081 - root_mean_squared_error: 11.0084 - val_loss: 116.9728 - val_root_mean_squared_error: 10.8154
# Epoch 5/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 124.4940 - root_mean_squared_error: 11.1570 - val_loss: 127.5134 - val_root_mean_squared_error: 11.2922
# Epoch 6/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 127.8824 - root_mean_squared_error: 11.3075 - val_loss: 118.5266 - val_root_mean_squared_error: 10.8870
# Epoch 7/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 127.5860 - root_mean_squared_error: 11.2945 - val_loss: 125.0461 - val_root_mean_squared_error: 11.1824
# Epoch 8/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 127.9899 - root_mean_squared_error: 11.3123 - val_loss: 129.8631 - val_root_mean_squared_error: 11.3958
# Epoch 9/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 132.7028 - root_mean_squared_error: 11.5184 - val_loss: 116.3424 - val_root_mean_squared_error: 10.7862
# Epoch 10/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 126.6056 - root_mean_squared_error: 11.2516 - val_loss: 115.5946 - val_root_mean_squared_error: 10.7515
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 112.7364 - root_mean_squared_error: 10.6166
# Epoch 1/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 204131021094912.0000 - root_mean_squared_error: 10994716.0000 - val_loss: 50268.3711 - val_root_mean_squared_error: 224.2061
# Epoch 2/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 117.9726 - root_mean_squared_error: 10.8610 - val_loss: 50275.6875 - val_root_mean_squared_error: 224.2224
# Epoch 3/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 117.0515 - root_mean_squared_error: 10.8188 - val_loss: 50277.0664 - val_root_mean_squared_error: 224.2255
# Epoch 4/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 118.1304 - root_mean_squared_error: 10.8684 - val_loss: 50270.7109 - val_root_mean_squared_error: 224.2113
# Epoch 5/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 120.1339 - root_mean_squared_error: 10.9602 - val_loss: 50246.7227 - val_root_mean_squared_error: 224.1578
# Epoch 6/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 122.2467 - root_mean_squared_error: 11.0561 - val_loss: 50257.9570 - val_root_mean_squared_error: 224.1829
# Epoch 7/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 123.6712 - root_mean_squared_error: 11.1192 - val_loss: 50373.6328 - val_root_mean_squared_error: 224.4407
# Epoch 8/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 128.4527 - root_mean_squared_error: 11.3331 - val_loss: 50425.0938 - val_root_mean_squared_error: 224.5553
# Epoch 9/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 136.0987 - root_mean_squared_error: 11.6614 - val_loss: 50852.0469 - val_root_mean_squared_error: 225.5040
# Epoch 10/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 175.0767 - root_mean_squared_error: 13.2124 - val_loss: 51572.8789 - val_root_mean_squared_error: 227.0966
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 156.7068 - root_mean_squared_error: 12.5162
# Epoch 1/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 65163733441183744.0000 - root_mean_squared_error: 193113664.0000 - val_loss: 3496123.7500 - val_root_mean_squared_error: 1869.7925
# Epoch 2/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 3455154.2500 - root_mean_squared_error: 1858.7920 - val_loss: 3290389.2500 - val_root_mean_squared_error: 1813.9430
# Epoch 3/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 3199917.2500 - root_mean_squared_error: 1788.7622 - val_loss: 2849796.5000 - val_root_mean_squared_error: 1688.1340
# Epoch 4/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 2676167.5000 - root_mean_squared_error: 1635.5751 - val_loss: 2046752.0000 - val_root_mean_squared_error: 1430.6475
# Epoch 5/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1782614.0000 - root_mean_squared_error: 1333.8588 - val_loss: 958535.6250 - val_root_mean_squared_error: 979.0483
# Epoch 6/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 716895.7500 - root_mean_squared_error: 843.1435 - val_loss: 168401.9688 - val_root_mean_squared_error: 410.3681
# Epoch 7/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 96047.9062 - root_mean_squared_error: 305.3619 - val_loss: 3197.9346 - val_root_mean_squared_error: 56.5503
# Epoch 8/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1554.2703 - root_mean_squared_error: 38.5677 - val_loss: 115.0587 - val_root_mean_squared_error: 10.7265
# Epoch 9/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 359.2447 - root_mean_squared_error: 18.6157 - val_loss: 114.6659 - val_root_mean_squared_error: 10.7082
# Epoch 10/50
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 330.8221 - root_mean_squared_error: 17.7445 - val_loss: 114.5395 - val_root_mean_squared_error: 10.7023
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 598.6768 - root_mean_squared_error: 22.1435
# Epoch 1/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 660576.3125 - root_mean_squared_error: 726.1243 - val_loss: 606.0816 - val_root_mean_squared_error: 24.6187
# Epoch 2/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 237.0124 - root_mean_squared_error: 15.1535 - val_loss: 114.0710 - val_root_mean_squared_error: 10.6804
# Epoch 3/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 96.1773 - root_mean_squared_error: 9.8063 - val_loss: 108.4821 - val_root_mean_squared_error: 10.4155
# Epoch 4/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 92.2964 - root_mean_squared_error: 9.6063 - val_loss: 103.9296 - val_root_mean_squared_error: 10.1946
# Epoch 5/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 91.8683 - root_mean_squared_error: 9.5836 - val_loss: 110.4540 - val_root_mean_squared_error: 10.5097
# Epoch 6/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 92.5841 - root_mean_squared_error: 9.6207 - val_loss: 142.9053 - val_root_mean_squared_error: 11.9543
# Epoch 7/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 95.4424 - root_mean_squared_error: 9.7677 - val_loss: 98.6865 - val_root_mean_squared_error: 9.9341
# Epoch 8/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 97.1777 - root_mean_squared_error: 9.8565 - val_loss: 90.4637 - val_root_mean_squared_error: 9.5112
# Epoch 9/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 106.6092 - root_mean_squared_error: 10.3234 - val_loss: 106.9987 - val_root_mean_squared_error: 10.3440
# Epoch 10/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 118.0167 - root_mean_squared_error: 10.8473 - val_loss: 126.0011 - val_root_mean_squared_error: 11.2250
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 121.5619 - root_mean_squared_error: 11.0251
# Epoch 1/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 299298.4688 - root_mean_squared_error: 463.9096 - val_loss: 114.7044 - val_root_mean_squared_error: 10.7100
# Epoch 2/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 99.8215 - root_mean_squared_error: 9.9904 - val_loss: 137.9038 - val_root_mean_squared_error: 11.7432
# Epoch 3/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 101.4555 - root_mean_squared_error: 10.0721 - val_loss: 107.7840 - val_root_mean_squared_error: 10.3819
# Epoch 4/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 107.1409 - root_mean_squared_error: 10.3500 - val_loss: 94.2337 - val_root_mean_squared_error: 9.7074
# Epoch 5/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 114.3835 - root_mean_squared_error: 10.6906 - val_loss: 229.5074 - val_root_mean_squared_error: 15.1495
# Epoch 6/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 145.1567 - root_mean_squared_error: 12.0332 - val_loss: 157.1412 - val_root_mean_squared_error: 12.5356
# Epoch 7/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 164.0230 - root_mean_squared_error: 12.7700 - val_loss: 88.7425 - val_root_mean_squared_error: 9.4203
# Epoch 8/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 165.6708 - root_mean_squared_error: 12.8386 - val_loss: 406.5174 - val_root_mean_squared_error: 20.1623
# Epoch 9/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 147.2757 - root_mean_squared_error: 12.1122 - val_loss: 84.3087 - val_root_mean_squared_error: 9.1820
# Epoch 10/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 166.5433 - root_mean_squared_error: 12.8885 - val_loss: 367.9056 - val_root_mean_squared_error: 19.1809
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 365.2375 - root_mean_squared_error: 19.1098
# Epoch 1/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 211584.6250 - root_mean_squared_error: 378.0026 - val_loss: 124.4562 - val_root_mean_squared_error: 11.1560
# Epoch 2/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 140.8616 - root_mean_squared_error: 11.8434 - val_loss: 276.8118 - val_root_mean_squared_error: 16.6377
# Epoch 3/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 166.6588 - root_mean_squared_error: 12.8868 - val_loss: 144.8869 - val_root_mean_squared_error: 12.0369
# Epoch 4/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 171.1140 - root_mean_squared_error: 13.0586 - val_loss: 719.9902 - val_root_mean_squared_error: 26.8326
# Epoch 5/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 291.8943 - root_mean_squared_error: 17.0586 - val_loss: 101.0630 - val_root_mean_squared_error: 10.0530
# Epoch 6/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 218.9727 - root_mean_squared_error: 14.7703 - val_loss: 1365.6936 - val_root_mean_squared_error: 36.9553
# Epoch 7/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 335.1544 - root_mean_squared_error: 17.9880 - val_loss: 716.8370 - val_root_mean_squared_error: 26.7738
# Epoch 8/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 247.2726 - root_mean_squared_error: 15.6893 - val_loss: 601.3807 - val_root_mean_squared_error: 24.5231
# Epoch 9/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 318.8775 - root_mean_squared_error: 17.7959 - val_loss: 624.6884 - val_root_mean_squared_error: 24.9938
# Epoch 10/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 274.0293 - root_mean_squared_error: 16.5334 - val_loss: 123.9033 - val_root_mean_squared_error: 11.1312
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 119.3576 - root_mean_squared_error: 10.9246
# Epoch 1/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 234926.5781 - root_mean_squared_error: 405.6376 - val_loss: 112.2796 - val_root_mean_squared_error: 10.5962
# Epoch 2/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 119.5921 - root_mean_squared_error: 10.9265 - val_loss: 338.2679 - val_root_mean_squared_error: 18.3921
# Epoch 3/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 139.0658 - root_mean_squared_error: 11.7682 - val_loss: 149.6015 - val_root_mean_squared_error: 12.2312
# Epoch 4/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 148.6285 - root_mean_squared_error: 12.1811 - val_loss: 677.4123 - val_root_mean_squared_error: 26.0271
# Epoch 5/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 214.9130 - root_mean_squared_error: 14.5808 - val_loss: 148.9210 - val_root_mean_squared_error: 12.2033
# Epoch 6/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 292.1895 - root_mean_squared_error: 17.0781 - val_loss: 496.4519 - val_root_mean_squared_error: 22.2812
# Epoch 7/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 307.4435 - root_mean_squared_error: 17.4656 - val_loss: 150.8302 - val_root_mean_squared_error: 12.2813
# Epoch 8/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 244.0600 - root_mean_squared_error: 15.6071 - val_loss: 86.1616 - val_root_mean_squared_error: 9.2823
# Epoch 9/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 252.0170 - root_mean_squared_error: 15.8523 - val_loss: 123.0329 - val_root_mean_squared_error: 11.0920
# Epoch 10/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 248.8284 - root_mean_squared_error: 15.7157 - val_loss: 80.8510 - val_root_mean_squared_error: 8.9917
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 76.2527 - root_mean_squared_error: 8.7304
# Epoch 1/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 453129.0312 - root_mean_squared_error: 542.0240 - val_loss: 112.2793 - val_root_mean_squared_error: 10.5962
# Epoch 2/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 455.7978 - root_mean_squared_error: 21.2544 - val_loss: 227.2331 - val_root_mean_squared_error: 15.0743
# Epoch 3/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 696.2673 - root_mean_squared_error: 26.3224 - val_loss: 1930.5087 - val_root_mean_squared_error: 43.9376
# Epoch 4/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 850.8788 - root_mean_squared_error: 29.0896 - val_loss: 214.8887 - val_root_mean_squared_error: 14.6591
# Epoch 5/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 968.9763 - root_mean_squared_error: 30.9160 - val_loss: 561.8058 - val_root_mean_squared_error: 23.7024
# Epoch 6/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 634.3387 - root_mean_squared_error: 25.0217 - val_loss: 1193.7064 - val_root_mean_squared_error: 34.5501
# Epoch 7/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 568.1703 - root_mean_squared_error: 23.7633 - val_loss: 261.8456 - val_root_mean_squared_error: 16.1816
# Epoch 8/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 475.8631 - root_mean_squared_error: 21.6983 - val_loss: 146.5240 - val_root_mean_squared_error: 12.1047
# Epoch 9/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 414.3420 - root_mean_squared_error: 20.3145 - val_loss: 603.9088 - val_root_mean_squared_error: 24.5746
# Epoch 10/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 420.2891 - root_mean_squared_error: 20.4471 - val_loss: 102.2423 - val_root_mean_squared_error: 10.1115
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 99.4017 - root_mean_squared_error: 9.9680
# Epoch 1/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 66633592.0000 - root_mean_squared_error: 6462.0156 - val_loss: 752.7213 - val_root_mean_squared_error: 27.4358
# Epoch 2/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 377.2965 - root_mean_squared_error: 18.7703 - val_loss: 753.0189 - val_root_mean_squared_error: 27.4412
# Epoch 3/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 426.7759 - root_mean_squared_error: 19.6339 - val_loss: 753.7444 - val_root_mean_squared_error: 27.4544
# Epoch 4/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 247.8599 - root_mean_squared_error: 15.4585 - val_loss: 752.5809 - val_root_mean_squared_error: 27.4332
# Epoch 5/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 408.9770 - root_mean_squared_error: 19.7095 - val_loss: 752.7122 - val_root_mean_squared_error: 27.4356
# Epoch 6/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 239.3035 - root_mean_squared_error: 15.1929 - val_loss: 753.1259 - val_root_mean_squared_error: 27.4431
# Epoch 7/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 236.6861 - root_mean_squared_error: 15.0645 - val_loss: 752.1923 - val_root_mean_squared_error: 27.4261
# Epoch 8/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 318.2362 - root_mean_squared_error: 17.4138 - val_loss: 753.0456 - val_root_mean_squared_error: 27.4417
# Epoch 9/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 191.4746 - root_mean_squared_error: 13.6354 - val_loss: 753.6782 - val_root_mean_squared_error: 27.4532
# Epoch 10/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 170.6288 - root_mean_squared_error: 12.8543 - val_loss: 751.5896 - val_root_mean_squared_error: 27.4151
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 319.8073 - root_mean_squared_error: 16.5517
# Epoch 1/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 1227519.3750 - root_mean_squared_error: 932.5314 - val_loss: 163.7263 - val_root_mean_squared_error: 12.7956
# Epoch 2/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 204.7560 - root_mean_squared_error: 14.2890 - val_loss: 295.9083 - val_root_mean_squared_error: 17.2020
# Epoch 3/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 291.0410 - root_mean_squared_error: 17.0272 - val_loss: 193.0550 - val_root_mean_squared_error: 13.8944
# Epoch 4/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 246.6911 - root_mean_squared_error: 15.6742 - val_loss: 151.1664 - val_root_mean_squared_error: 12.2950
# Epoch 5/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 303.9425 - root_mean_squared_error: 17.3496 - val_loss: 643.3967 - val_root_mean_squared_error: 25.3653
# Epoch 6/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 365.2571 - root_mean_squared_error: 18.9882 - val_loss: 156.0204 - val_root_mean_squared_error: 12.4908
# Epoch 7/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 296.5624 - root_mean_squared_error: 17.1913 - val_loss: 160.6866 - val_root_mean_squared_error: 12.6762
# Epoch 8/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 313.5001 - root_mean_squared_error: 17.6958 - val_loss: 109.2857 - val_root_mean_squared_error: 10.4540
# Epoch 9/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 1516265.1250 - root_mean_squared_error: 830.1179 - val_loss: 1403288.8750 - val_root_mean_squared_error: 1184.6050
# Epoch 10/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 884581.4375 - root_mean_squared_error: 931.8526 - val_loss: 122656.5938 - val_root_mean_squared_error: 350.2236
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 122623.7578 - root_mean_squared_error: 350.1767
# Epoch 1/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 31962190315520.0000 - root_mean_squared_error: 4524857.5000 - val_loss: 114.5515 - val_root_mean_squared_error: 10.7029
# Epoch 2/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 117.4702 - root_mean_squared_error: 10.8381 - val_loss: 114.5317 - val_root_mean_squared_error: 10.7019
# Epoch 3/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 120.8274 - root_mean_squared_error: 10.9908 - val_loss: 115.3669 - val_root_mean_squared_error: 10.7409
# Epoch 4/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 118.0086 - root_mean_squared_error: 10.8629 - val_loss: 114.6911 - val_root_mean_squared_error: 10.7094
# Epoch 5/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 116.9648 - root_mean_squared_error: 10.8146 - val_loss: 116.1619 - val_root_mean_squared_error: 10.7778
# Epoch 6/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 117.1976 - root_mean_squared_error: 10.8250 - val_loss: 115.2526 - val_root_mean_squared_error: 10.7356
# Epoch 7/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 118.6025 - root_mean_squared_error: 10.8902 - val_loss: 114.9213 - val_root_mean_squared_error: 10.7201
# Epoch 8/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 117.3217 - root_mean_squared_error: 10.8307 - val_loss: 122.2267 - val_root_mean_squared_error: 11.0556
# Epoch 9/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 120.3987 - root_mean_squared_error: 10.9721 - val_loss: 118.1526 - val_root_mean_squared_error: 10.8698
# Epoch 10/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 123.0133 - root_mean_squared_error: 11.0901 - val_loss: 115.2817 - val_root_mean_squared_error: 10.7369
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 112.4377 - root_mean_squared_error: 10.6025
# Epoch 1/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 22915888202121216.0000 - root_mean_squared_error: 119073496.0000 - val_loss: 3856915.0000 - val_root_mean_squared_error: 1963.9030
# Epoch 2/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 3855528.7500 - root_mean_squared_error: 1963.5500 - val_loss: 3852501.5000 - val_root_mean_squared_error: 1962.7791
# Epoch 3/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3850193.7500 - root_mean_squared_error: 1962.1910 - val_loss: 3845101.7500 - val_root_mean_squared_error: 1960.8931
# Epoch 4/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 3841930.2500 - root_mean_squared_error: 1960.0842 - val_loss: 3833496.0000 - val_root_mean_squared_error: 1957.9315
# Epoch 5/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 3828410.0000 - root_mean_squared_error: 1956.6322 - val_loss: 3815719.0000 - val_root_mean_squared_error: 1953.3866
# Epoch 6/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3808655.7500 - root_mean_squared_error: 1951.5775 - val_loss: 3789452.2500 - val_root_mean_squared_error: 1946.6515
# Epoch 7/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3780397.2500 - root_mean_squared_error: 1944.3240 - val_loss: 3752459.0000 - val_root_mean_squared_error: 1937.1265
# Epoch 8/50
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3739198.7500 - root_mean_squared_error: 1933.7000 - val_loss: 3698710.2500 - val_root_mean_squared_error: 1923.2031
# Epoch 9/50
# ...
# Epoch 2/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 544.9797 - root_mean_squared_error: 22.6364 - val_loss: 129.9368 - val_root_mean_squared_error: 11.3990
# Epoch 3/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 100.4896 - root_mean_squared_error: 10.0237 - val_loss: 126.7414 - val_root_mean_squared_error: 11.2579
# Epoch 4/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 94.0555 - root_mean_squared_error: 9.6978 - val_loss: 111.7076 - val_root_mean_squared_error: 10.5692
# Epoch 5/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 93.4983 - root_mean_squared_error: 9.6691 - val_loss: 110.7222 - val_root_mean_squared_error: 10.5225
# Epoch 6/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 93.3753 - root_mean_squared_error: 9.6619 - val_loss: 102.6236 - val_root_mean_squared_error: 10.1303
# Epoch 7/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 94.2947 - root_mean_squared_error: 9.7083 - val_loss: 135.0491 - val_root_mean_squared_error: 11.6211
# Epoch 8/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 99.3983 - root_mean_squared_error: 9.9683 - val_loss: 95.2458 - val_root_mean_squared_error: 9.7594
# Epoch 9/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 101.8953 - root_mean_squared_error: 10.0871 - val_loss: 171.4608 - val_root_mean_squared_error: 13.0943
# Epoch 10/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 100.7145 - root_mean_squared_error: 10.0335 - val_loss: 83.2976 - val_root_mean_squared_error: 9.1268
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 78.6897 - root_mean_squared_error: 8.8693
# Epoch 1/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 301456.0312 - root_mean_squared_error: 464.7160 - val_loss: 132.4396 - val_root_mean_squared_error: 11.5082
# Epoch 2/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 98.9518 - root_mean_squared_error: 9.9465 - val_loss: 123.8259 - val_root_mean_squared_error: 11.1277
# Epoch 3/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 98.9121 - root_mean_squared_error: 9.9434 - val_loss: 144.0210 - val_root_mean_squared_error: 12.0009
# Epoch 4/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 125.7231 - root_mean_squared_error: 11.2089 - val_loss: 363.3672 - val_root_mean_squared_error: 19.0622
# Epoch 5/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 142.8531 - root_mean_squared_error: 11.9361 - val_loss: 199.8532 - val_root_mean_squared_error: 14.1369
# Epoch 6/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 130.6458 - root_mean_squared_error: 11.4167 - val_loss: 81.1093 - val_root_mean_squared_error: 9.0061
# Epoch 7/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 168.7429 - root_mean_squared_error: 12.9501 - val_loss: 671.4594 - val_root_mean_squared_error: 25.9125
# Epoch 8/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 180.2115 - root_mean_squared_error: 13.3889 - val_loss: 82.3043 - val_root_mean_squared_error: 9.0722
# Epoch 9/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 157.2985 - root_mean_squared_error: 12.5150 - val_loss: 79.4776 - val_root_mean_squared_error: 8.9150
# Epoch 10/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 156.2443 - root_mean_squared_error: 12.4899 - val_loss: 108.9296 - val_root_mean_squared_error: 10.4369
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 104.8560 - root_mean_squared_error: 10.2376
# Epoch 1/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 226934.3594 - root_mean_squared_error: 396.6068 - val_loss: 170.4160 - val_root_mean_squared_error: 13.0543
# Epoch 2/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 103.7469 - root_mean_squared_error: 10.1848 - val_loss: 185.0827 - val_root_mean_squared_error: 13.6045
# Epoch 3/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 126.3704 - root_mean_squared_error: 11.2359 - val_loss: 104.0996 - val_root_mean_squared_error: 10.2029
# Epoch 4/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 160.0310 - root_mean_squared_error: 12.6366 - val_loss: 95.0061 - val_root_mean_squared_error: 9.7471
# Epoch 5/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 189.5507 - root_mean_squared_error: 13.7100 - val_loss: 314.9192 - val_root_mean_squared_error: 17.7460
# Epoch 6/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 217.7796 - root_mean_squared_error: 14.7020 - val_loss: 80.6667 - val_root_mean_squared_error: 8.9815
# Epoch 7/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 407.6313 - root_mean_squared_error: 19.9432 - val_loss: 85.0276 - val_root_mean_squared_error: 9.2210
# Epoch 8/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 245.2393 - root_mean_squared_error: 15.6210 - val_loss: 378.6082 - val_root_mean_squared_error: 19.4579
# Epoch 9/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 258.6281 - root_mean_squared_error: 16.0245 - val_loss: 1325.1013 - val_root_mean_squared_error: 36.4019
# Epoch 10/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 276.3849 - root_mean_squared_error: 16.5001 - val_loss: 302.4180 - val_root_mean_squared_error: 17.3902
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 294.5048 - root_mean_squared_error: 17.1608
# Epoch 1/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 253150.6406 - root_mean_squared_error: 422.1203 - val_loss: 104.9045 - val_root_mean_squared_error: 10.2423
# Epoch 2/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 102.5557 - root_mean_squared_error: 10.1257 - val_loss: 177.7514 - val_root_mean_squared_error: 13.3323
# Epoch 3/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 111.6975 - root_mean_squared_error: 10.5647 - val_loss: 367.9339 - val_root_mean_squared_error: 19.1816
# Epoch 4/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 130.1402 - root_mean_squared_error: 11.3968 - val_loss: 190.6218 - val_root_mean_squared_error: 13.8066
# Epoch 5/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 165.3555 - root_mean_squared_error: 12.8536 - val_loss: 984.0942 - val_root_mean_squared_error: 31.3703
# Epoch 6/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 221.2359 - root_mean_squared_error: 14.8090 - val_loss: 189.4037 - val_root_mean_squared_error: 13.7624
# Epoch 7/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 293.8449 - root_mean_squared_error: 17.1225 - val_loss: 320.9995 - val_root_mean_squared_error: 17.9165
# Epoch 8/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 244.8817 - root_mean_squared_error: 15.6302 - val_loss: 128.6807 - val_root_mean_squared_error: 11.3438
# Epoch 9/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 215.0655 - root_mean_squared_error: 14.6471 - val_loss: 1498.8478 - val_root_mean_squared_error: 38.7150
# Epoch 10/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 267.3836 - root_mean_squared_error: 16.2553 - val_loss: 343.2597 - val_root_mean_squared_error: 18.5273
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 341.9138 - root_mean_squared_error: 18.4897
# Epoch 1/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 338808.0625 - root_mean_squared_error: 477.7741 - val_loss: 1443.9896 - val_root_mean_squared_error: 37.9999
# Epoch 2/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 587.9705 - root_mean_squared_error: 24.0811 - val_loss: 1709.5781 - val_root_mean_squared_error: 41.3470
# Epoch 3/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 26223.4355 - root_mean_squared_error: 144.3293 - val_loss: 193.4924 - val_root_mean_squared_error: 13.9102
# Epoch 4/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 173.2544 - root_mean_squared_error: 13.1473 - val_loss: 348.4178 - val_root_mean_squared_error: 18.6660
# Epoch 5/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 365.9410 - root_mean_squared_error: 18.9733 - val_loss: 738.3788 - val_root_mean_squared_error: 27.1731
# Epoch 6/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 847.9703 - root_mean_squared_error: 29.0150 - val_loss: 1045.0714 - val_root_mean_squared_error: 32.3276
# Epoch 7/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 660.9657 - root_mean_squared_error: 25.6803 - val_loss: 149.7483 - val_root_mean_squared_error: 12.2372
# Epoch 8/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 474.0163 - root_mean_squared_error: 21.5884 - val_loss: 542.0765 - val_root_mean_squared_error: 23.2825
# Epoch 9/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 496.1337 - root_mean_squared_error: 22.2436 - val_loss: 111.0157 - val_root_mean_squared_error: 10.5364
# Epoch 10/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 440.8788 - root_mean_squared_error: 20.9469 - val_loss: 353.1952 - val_root_mean_squared_error: 18.7935
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 351.8238 - root_mean_squared_error: 18.7555
# Epoch 1/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 52294436.0000 - root_mean_squared_error: 5872.1401 - val_loss: 1855522.3750 - val_root_mean_squared_error: 1362.1757
# Epoch 2/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1394963.3750 - root_mean_squared_error: 1176.6101 - val_loss: 414068.0000 - val_root_mean_squared_error: 643.4811
# Epoch 3/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 272102.9062 - root_mean_squared_error: 517.4595 - val_loss: 39697.4375 - val_root_mean_squared_error: 199.2422
# Epoch 4/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 22031.6680 - root_mean_squared_error: 146.1515 - val_loss: 1148.0026 - val_root_mean_squared_error: 33.8822
# Epoch 5/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 573.9794 - root_mean_squared_error: 23.5541 - val_loss: 119.1243 - val_root_mean_squared_error: 10.9144
# Epoch 6/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 119.5655 - root_mean_squared_error: 10.9343 - val_loss: 114.5930 - val_root_mean_squared_error: 10.7048
# Epoch 7/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 120.3678 - root_mean_squared_error: 10.9696 - val_loss: 114.5536 - val_root_mean_squared_error: 10.7030
# Epoch 8/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 118.6318 - root_mean_squared_error: 10.8897 - val_loss: 114.6101 - val_root_mean_squared_error: 10.7056
# Epoch 9/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 116.9102 - root_mean_squared_error: 10.8119 - val_loss: 114.5308 - val_root_mean_squared_error: 10.7019
# Epoch 10/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 118.3583 - root_mean_squared_error: 10.8788 - val_loss: 114.5811 - val_root_mean_squared_error: 10.7043
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 111.8311 - root_mean_squared_error: 10.5736
# Epoch 1/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 2341326.2500 - root_mean_squared_error: 1298.6881 - val_loss: 1008.0555 - val_root_mean_squared_error: 31.7499
# Epoch 2/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 1054.0603 - root_mean_squared_error: 31.4917 - val_loss: 149.7705 - val_root_mean_squared_error: 12.2381
# Epoch 3/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 423.2520 - root_mean_squared_error: 20.4036 - val_loss: 327.0063 - val_root_mean_squared_error: 18.0833
# Epoch 4/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 34730.1211 - root_mean_squared_error: 124.8448 - val_loss: 117.1389 - val_root_mean_squared_error: 10.8231
# Epoch 5/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 128.0710 - root_mean_squared_error: 11.3150 - val_loss: 117.3637 - val_root_mean_squared_error: 10.8335
# Epoch 6/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 139.0793 - root_mean_squared_error: 11.7894 - val_loss: 173.2630 - val_root_mean_squared_error: 13.1629
# Epoch 7/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 168.1494 - root_mean_squared_error: 12.9626 - val_loss: 331.6079 - val_root_mean_squared_error: 18.2101
# Epoch 8/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 295.3960 - root_mean_squared_error: 17.1027 - val_loss: 120.8268 - val_root_mean_squared_error: 10.9921
# Epoch 9/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 675.6508 - root_mean_squared_error: 25.8611 - val_loss: 122.9947 - val_root_mean_squared_error: 11.0903
# Epoch 10/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 702.6816 - root_mean_squared_error: 26.3249 - val_loss: 735.7413 - val_root_mean_squared_error: 27.1246
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 735.1166 - root_mean_squared_error: 27.1121
# Epoch 1/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 48838962315264.0000 - root_mean_squared_error: 5531256.0000 - val_loss: 114.6821 - val_root_mean_squared_error: 10.7090
# Epoch 2/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 118.9525 - root_mean_squared_error: 10.9058 - val_loss: 114.5345 - val_root_mean_squared_error: 10.7021
# Epoch 3/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 117.1774 - root_mean_squared_error: 10.8245 - val_loss: 114.6902 - val_root_mean_squared_error: 10.7094
# Epoch 4/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 119.1929 - root_mean_squared_error: 10.9172 - val_loss: 114.6555 - val_root_mean_squared_error: 10.7077
# Epoch 5/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 118.9075 - root_mean_squared_error: 10.9041 - val_loss: 114.6137 - val_root_mean_squared_error: 10.7058
# Epoch 6/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 119.9339 - root_mean_squared_error: 10.9506 - val_loss: 114.5826 - val_root_mean_squared_error: 10.7043
# Epoch 7/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 120.5233 - root_mean_squared_error: 10.9774 - val_loss: 114.6799 - val_root_mean_squared_error: 10.7089
# Epoch 8/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 117.7682 - root_mean_squared_error: 10.8518 - val_loss: 118.5665 - val_root_mean_squared_error: 10.8888
# Epoch 9/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 118.6738 - root_mean_squared_error: 10.8934 - val_loss: 114.8417 - val_root_mean_squared_error: 10.7164
# Epoch 10/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 122.2368 - root_mean_squared_error: 11.0555 - val_loss: 114.9400 - val_root_mean_squared_error: 10.7210
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 112.1155 - root_mean_squared_error: 10.5872
# Epoch 1/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 59898722011578368.0000 - root_mean_squared_error: 192775936.0000 - val_loss: 3955243.7500 - val_root_mean_squared_error: 1988.7794
# Epoch 2/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 3950798.7500 - root_mean_squared_error: 1987.6615 - val_loss: 3936678.7500 - val_root_mean_squared_error: 1984.1066
# Epoch 3/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 3928831.2500 - root_mean_squared_error: 1982.1276 - val_loss: 3902477.7500 - val_root_mean_squared_error: 1975.4690
# Epoch 4/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 3888652.5000 - root_mean_squared_error: 1971.9656 - val_loss: 3839271.0000 - val_root_mean_squared_error: 1959.4058
# Epoch 5/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 3814389.7500 - root_mean_squared_error: 1953.0427 - val_loss: 3729683.0000 - val_root_mean_squared_error: 1931.2388
# Epoch 6/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 3692433.7500 - root_mean_squared_error: 1921.5620 - val_loss: 3567179.2500 - val_root_mean_squared_error: 1888.6978
# Epoch 7/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3513905.5000 - root_mean_squared_error: 1874.5221 - val_loss: 3333899.0000 - val_root_mean_squared_error: 1825.8967
# Epoch 8/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 3258683.2500 - root_mean_squared_error: 1805.1406 - val_loss: 3008848.2500 - val_root_mean_squared_error: 1734.6031
# Epoch 9/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2907711.7500 - root_mean_squared_error: 1705.1102 - val_loss: 2574790.0000 - val_root_mean_squared_error: 1604.6152
# Epoch 10/100
# 827/827 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 2444886.5000 - root_mean_squared_error: 1563.4230 - val_loss: 2028649.1250 - val_root_mean_squared_error: 1424.3065
# Epoch 10: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2028523.6250 - root_mean_squared_error: 1424.2625

# %%
# Flatten the list of tuples
flattened_data = [item for sublist in resultado_adam_opt for item in sublist]

# Convert the flattened data into a DataFrame
df = pd.DataFrame(flattened_data, columns=['Epocas', 'RMSE', 'Batch Size', 'Learning Rate'])

# Order the DataFrame by the third position (Value3) in ascending order
df_sorted = df.sort_values(by='RMSE', ascending=True)

df_sorted.head(10)
# Out:
#     Epocas       RMSE  Batch Size  Learning Rate
# 21      50   8.885938          64          0.010
# 36     100   8.917037          32          0.001
# 45     100   8.994738          64          0.001
# 0       50   9.769394          16          0.001
# 22      50  10.095973          64          0.050
# 46     100  10.405894          64          0.005
# 11      50  10.676520          32          0.009
# 12      50  10.683104          32          0.010
# 8       50  10.693462          16          0.900
# 7       50  10.693480          16          0.500

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)


optimizer = Adam(learning_rate=0.001)
optimizer1 = Adam(learning_rate=0.001)
optimizer2 = Adam(learning_rate=0.001)
optimizer3 = Adam(learning_rate=0.001)

model = Sequential()
model.add(Dense(502, activation='relu', input_shape=(X_train_scaled.shape[1],)))
model.add(Dense(256, activation='elu'))
model.add(Dense(128, activation='elu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='elu'))
model.add(Dense(1, activation='linear'))


model1 = Sequential()
model1.add(Dense(502, activation='relu', input_shape=(X_train_scaled.shape[1],), kernel_regularizer=regularizers.l1(0.01)))
model1.add(Dense(256, activation='elu', kernel_regularizer=regularizers.l1(0.01)))
model1.add(Dense(128, activation='elu', kernel_regularizer=regularizers.l1(0.01)))
model1.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l1(0.01)))
model1.add(Dense(32, activation='elu', kernel_regularizer=regularizers.l1(0.01)))
model1.add(Dense(1, activation='linear'))


model2 = Sequential()
model2.add(Dense(502, activation='relu', input_shape=(X_train_scaled.shape[1],), kernel_regularizer=regularizers.l1(0.001)))
model2.add(Dense(256, activation='elu', kernel_regularizer=regularizers.l1(0.001)))
model2.add(Dense(128, activation='elu', kernel_regularizer=regularizers.l1(0.001)))
model2.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l1(0.001)))
model2.add(Dense(32, activation='elu', kernel_regularizer=regularizers.l1(0.001)))
model2.add(Dense(1, activation='linear'))

model3 = Sequential()
model3.add(Dense(502, activation='relu', input_shape=(X_train_scaled.shape[1],)))
model3.add(Dropout(0.05))
model3.add(Dense(256, activation='elu'))
model3.add(Dropout(0.05))
model3.add(Dense(128, activation='elu'))
model3.add(Dropout(0.05))
model3.add(Dense(64, activation='relu'))
model3.add(Dropout(0.05))
model3.add(Dense(32, activation='elu'))
model3.add(Dropout(0.05))
model3.add(Dense(1, activation='linear'))


model.compile(loss=MeanSquaredError(), optimizer=optimizer, metrics=[RootMeanSquaredError()])
model1.compile(loss=MeanSquaredError(), optimizer=optimizer1, metrics=[RootMeanSquaredError()])
model2.compile(loss=MeanSquaredError(), optimizer=optimizer2, metrics=[RootMeanSquaredError()])
model3.compile(loss=MeanSquaredError(), optimizer=optimizer3, metrics=[RootMeanSquaredError()])



model.fit(X_train_scaled, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1, callbacks=[es])
model1.fit(X_train_scaled, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1, callbacks=[es])
model2.fit(X_train_scaled, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1, callbacks=[es])
model3.fit(X_train_scaled, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1, callbacks=[es])



result = model.evaluate(X_val_scaled, y_val, return_dict=True)
result1 = model1.evaluate(X_val_scaled, y_val, return_dict=True)
result2 = model2.evaluate(X_val_scaled, y_val, return_dict=True)
result3 = model3.evaluate(X_val_scaled, y_val, return_dict=True)
# Out:
# Epoch 1/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 424631.4688 - root_mean_squared_error: 565.2690 - val_loss: 150.0727 - val_root_mean_squared_error: 12.2504
# Epoch 2/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 105.8027 - root_mean_squared_error: 10.2846 - val_loss: 121.0818 - val_root_mean_squared_error: 11.0037
# Epoch 3/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 98.7045 - root_mean_squared_error: 9.9346 - val_loss: 109.1671 - val_root_mean_squared_error: 10.4483
# Epoch 4/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 106.1312 - root_mean_squared_error: 10.3002 - val_loss: 205.0776 - val_root_mean_squared_error: 14.3205
# Epoch 5/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 110.6587 - root_mean_squared_error: 10.5167 - val_loss: 92.5269 - val_root_mean_squared_error: 9.6191
# Epoch 6/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 114.4940 - root_mean_squared_error: 10.6975 - val_loss: 83.1520 - val_root_mean_squared_error: 9.1188
# Epoch 7/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 101.9104 - root_mean_squared_error: 10.0944 - val_loss: 181.9055 - val_root_mean_squared_error: 13.4872
# Epoch 8/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 110.7721 - root_mean_squared_error: 10.5217 - val_loss: 97.8502 - val_root_mean_squared_error: 9.8919
# Epoch 9/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 99.1775 - root_mean_squared_error: 9.9561 - val_loss: 84.0804 - val_root_mean_squared_error: 9.1695
# Epoch 10/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 100.3869 - root_mean_squared_error: 10.0151 - val_loss: 89.1305 - val_root_mean_squared_error: 9.4409
# Epoch 11/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 100.7122 - root_mean_squared_error: 10.0334 - val_loss: 154.5723 - val_root_mean_squared_error: 12.4327
# Epoch 12/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 92.1686 - root_mean_squared_error: 9.5982 - val_loss: 100.1431 - val_root_mean_squared_error: 10.0072
# Epoch 13/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 89.9363 - root_mean_squared_error: 9.4824 - val_loss: 106.5887 - val_root_mean_squared_error: 10.3242
# Epoch 14/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 95.8919 - root_mean_squared_error: 9.7881 - val_loss: 79.0636 - val_root_mean_squared_error: 8.8918
# Epoch 15/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 92.1378 - root_mean_squared_error: 9.5976 - val_loss: 80.4011 - val_root_mean_squared_error: 8.9667
# Epoch 16/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 86.9663 - root_mean_squared_error: 9.3241 - val_loss: 102.4867 - val_root_mean_squared_error: 10.1236
# Epoch 17/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 84.1706 - root_mean_squared_error: 9.1723 - val_loss: 78.7668 - val_root_mean_squared_error: 8.8751
# Epoch 18/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 86.9987 - root_mean_squared_error: 9.3233 - val_loss: 160.3433 - val_root_mean_squared_error: 12.6627
# Epoch 19/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 81.1034 - root_mean_squared_error: 9.0041 - val_loss: 138.3549 - val_root_mean_squared_error: 11.7624
# Epoch 20/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 75.6583 - root_mean_squared_error: 8.6936 - val_loss: 93.0193 - val_root_mean_squared_error: 9.6447
# Epoch 21/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 75.8740 - root_mean_squared_error: 8.7086 - val_loss: 131.2446 - val_root_mean_squared_error: 11.4562
# Epoch 22/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 72.9011 - root_mean_squared_error: 8.5371 - val_loss: 81.7550 - val_root_mean_squared_error: 9.0418
# Epoch 23/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.9254 - root_mean_squared_error: 8.4203 - val_loss: 81.9807 - val_root_mean_squared_error: 9.0543
# Epoch 24/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 73.4254 - root_mean_squared_error: 8.5674 - val_loss: 109.2688 - val_root_mean_squared_error: 10.4532
# Epoch 25/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 66.9196 - root_mean_squared_error: 8.1773 - val_loss: 137.9333 - val_root_mean_squared_error: 11.7445
# Epoch 26/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 65.5412 - root_mean_squared_error: 8.0923 - val_loss: 109.5316 - val_root_mean_squared_error: 10.4657
# Epoch 27/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 66.6386 - root_mean_squared_error: 8.1614 - val_loss: 105.8583 - val_root_mean_squared_error: 10.2887
# Epoch 28/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 61.4391 - root_mean_squared_error: 7.8367 - val_loss: 81.3659 - val_root_mean_squared_error: 9.0203
# Epoch 29/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 60.7690 - root_mean_squared_error: 7.7902 - val_loss: 104.9227 - val_root_mean_squared_error: 10.2432
# Epoch 30/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 62.8273 - root_mean_squared_error: 7.9235 - val_loss: 83.1542 - val_root_mean_squared_error: 9.1189
# Epoch 31/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 59.5549 - root_mean_squared_error: 7.7143 - val_loss: 95.4981 - val_root_mean_squared_error: 9.7723
# Epoch 32/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 59.7164 - root_mean_squared_error: 7.7249 - val_loss: 100.5804 - val_root_mean_squared_error: 10.0290
# Epoch 32: early stopping
# Epoch 1/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 416925.7500 - root_mean_squared_error: 557.7578 - val_loss: 268.0178 - val_root_mean_squared_error: 11.6224
# Epoch 2/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 232.5277 - root_mean_squared_error: 10.0675 - val_loss: 244.0582 - val_root_mean_squared_error: 10.9358
# Epoch 3/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 225.9795 - root_mean_squared_error: 10.2119 - val_loss: 214.7244 - val_root_mean_squared_error: 10.0347
# Epoch 4/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 223.3980 - root_mean_squared_error: 10.5507 - val_loss: 202.1339 - val_root_mean_squared_error: 9.7292
# Epoch 5/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 224.7863 - root_mean_squared_error: 10.9042 - val_loss: 225.2796 - val_root_mean_squared_error: 11.1162
# Epoch 6/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 209.6058 - root_mean_squared_error: 10.4799 - val_loss: 244.1598 - val_root_mean_squared_error: 12.3070
# Epoch 7/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 199.4064 - root_mean_squared_error: 10.4265 - val_loss: 172.7932 - val_root_mean_squared_error: 9.5642
# Epoch 8/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 183.8271 - root_mean_squared_error: 10.3060 - val_loss: 260.9723 - val_root_mean_squared_error: 13.9050
# Epoch 9/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 165.2906 - root_mean_squared_error: 10.0399 - val_loss: 269.1888 - val_root_mean_squared_error: 14.5565
# Epoch 10/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 154.4806 - root_mean_squared_error: 9.9752 - val_loss: 133.9716 - val_root_mean_squared_error: 9.2152
# Epoch 11/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 147.8152 - root_mean_squared_error: 10.0119 - val_loss: 153.2346 - val_root_mean_squared_error: 10.4755
# Epoch 12/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 137.8134 - root_mean_squared_error: 9.7833 - val_loss: 150.8772 - val_root_mean_squared_error: 10.5883
# Epoch 13/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 134.9565 - root_mean_squared_error: 9.8337 - val_loss: 115.4862 - val_root_mean_squared_error: 8.8950
# Epoch 14/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 127.6091 - root_mean_squared_error: 9.5892 - val_loss: 125.4807 - val_root_mean_squared_error: 9.5545
# Epoch 15/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 126.6151 - root_mean_squared_error: 9.6279 - val_loss: 112.3111 - val_root_mean_squared_error: 8.8930
# Epoch 15: early stopping
# Epoch 1/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 431552.0000 - root_mean_squared_error: 567.4248 - val_loss: 184.7818 - val_root_mean_squared_error: 13.0815
# Epoch 2/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 113.4177 - root_mean_squared_error: 9.9889 - val_loss: 161.8590 - val_root_mean_squared_error: 12.1786
# Epoch 3/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 114.5763 - root_mean_squared_error: 10.0535 - val_loss: 223.2541 - val_root_mean_squared_error: 14.4894
# Epoch 4/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 126.8201 - root_mean_squared_error: 10.6564 - val_loss: 120.2184 - val_root_mean_squared_error: 10.3615
# Epoch 5/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 123.4689 - root_mean_squared_error: 10.5226 - val_loss: 220.8323 - val_root_mean_squared_error: 14.4446
# Epoch 6/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 124.7032 - root_mean_squared_error: 10.6020 - val_loss: 129.9139 - val_root_mean_squared_error: 10.8676
# Epoch 7/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 114.8204 - root_mean_squared_error: 10.1544 - val_loss: 116.2242 - val_root_mean_squared_error: 10.2311
# Epoch 8/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 112.0484 - root_mean_squared_error: 10.0339 - val_loss: 104.6806 - val_root_mean_squared_error: 9.6762
# Epoch 9/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 105.8792 - root_mean_squared_error: 9.7410 - val_loss: 91.1142 - val_root_mean_squared_error: 8.9653
# Epoch 10/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 103.8240 - root_mean_squared_error: 9.6507 - val_loss: 115.5258 - val_root_mean_squared_error: 10.2464
# Epoch 11/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 104.8582 - root_mean_squared_error: 9.7154 - val_loss: 104.5586 - val_root_mean_squared_error: 9.7177
# Epoch 12/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 104.3613 - root_mean_squared_error: 9.7036 - val_loss: 188.8075 - val_root_mean_squared_error: 13.3713
# Epoch 13/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 101.3942 - root_mean_squared_error: 9.5606 - val_loss: 97.3217 - val_root_mean_squared_error: 9.3515
# Epoch 14/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 101.0475 - root_mean_squared_error: 9.5511 - val_loss: 100.8813 - val_root_mean_squared_error: 9.5546
# Epoch 15/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 91.6340 - root_mean_squared_error: 9.0547 - val_loss: 92.9573 - val_root_mean_squared_error: 9.1347
# Epoch 15: early stopping
# Epoch 1/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 449393.3438 - root_mean_squared_error: 589.2675 - val_loss: 2436.1479 - val_root_mean_squared_error: 49.3573
# Epoch 2/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 23349.7051 - root_mean_squared_error: 152.8015 - val_loss: 912.9203 - val_root_mean_squared_error: 30.2146
# Epoch 3/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 21797.5391 - root_mean_squared_error: 147.6368 - val_loss: 182.5746 - val_root_mean_squared_error: 13.5120
# Epoch 4/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 21027.1445 - root_mean_squared_error: 144.9980 - val_loss: 4046.3237 - val_root_mean_squared_error: 63.6107
# Epoch 5/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 19486.1758 - root_mean_squared_error: 139.5877 - val_loss: 7053.4116 - val_root_mean_squared_error: 83.9846
# Epoch 6/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 18039.7598 - root_mean_squared_error: 134.3081 - val_loss: 1600.7554 - val_root_mean_squared_error: 40.0094
# Epoch 7/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 16952.6035 - root_mean_squared_error: 130.1824 - val_loss: 14518.2051 - val_root_mean_squared_error: 120.4915
# Epoch 8/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 16112.1943 - root_mean_squared_error: 126.9199 - val_loss: 7021.9580 - val_root_mean_squared_error: 83.7971
# Epoch 9/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 15395.9902 - root_mean_squared_error: 124.0756 - val_loss: 10554.4053 - val_root_mean_squared_error: 102.7346
# Epoch 10/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 15358.9668 - root_mean_squared_error: 123.9100 - val_loss: 14992.1777 - val_root_mean_squared_error: 122.4426
# Epoch 11/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 14844.9639 - root_mean_squared_error: 121.8383 - val_loss: 10362.7012 - val_root_mean_squared_error: 101.7974
# Epoch 12/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 15298.7627 - root_mean_squared_error: 123.6759 - val_loss: 15692.1562 - val_root_mean_squared_error: 125.2683
# Epoch 13/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 14488.5186 - root_mean_squared_error: 120.3547 - val_loss: 20567.2715 - val_root_mean_squared_error: 143.4129
# Epoch 14/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 14416.7734 - root_mean_squared_error: 120.0657 - val_loss: 11644.4854 - val_root_mean_squared_error: 107.9096
# Epoch 15/100
# 1653/1653 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 14412.1963 - root_mean_squared_error: 120.0489 - val_loss: 19628.3164 - val_root_mean_squared_error: 140.1011
# Epoch 15: early stopping
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 93.5181 - root_mean_squared_error: 9.6694
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 109.1475 - root_mean_squared_error: 8.7107
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 90.4397 - root_mean_squared_error: 8.9930
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 19596.8789 - root_mean_squared_error: 139.9887

# %%
model.summary()
# Out:
# Model: "sequential_129"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_760 (Dense)               │ (None, 502)            │        39,658 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_761 (Dense)               │ (None, 256)            │       128,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_762 (Dense)               │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_763 (Dense)               │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_764 (Dense)               │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_765 (Dense)               │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 635,075 (2.42 MB)
#  Trainable params: 211,691 (826.92 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 423,384 (1.62 MB)

# %%
# Modelo
model = Sequential([
    Dense(160, input_dim=X_train_scaled.shape[1], activation='elu'),
    BatchNormalization(),
    Dense(80, activation='elu'),
    BatchNormalization(),
    Dense(45, activation='elu'),
    BatchNormalization(),
    Dense(25, activation='relu'),
    BatchNormalization(),
    Dense(20, activation='relu'),
    BatchNormalization(),
    Dense(1, activation='linear')  # Salida para regresión
])

# Compilación con Adam
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mean_squared_error')

# Callback de EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)

# Entrenamiento con EarlyStopping
model.fit(X_train_scaled, y_train, epochs=50, batch_size=32, validation_data=(X_val_scaled, y_val), callbacks=[early_stopping])

# Evaluación
y_pred = model.predict(X_val_scaled)
if np.isnan(y_pred).any():
    raise ValueError("Las predicciones contienen NaN")

rmse = sqrt(mean_squared_error(y_val, y_pred))
print(f'RMSE: {rmse}')
# Out:
# c:\Users\Usuario\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 3913831.5000 - val_loss: 3267433.0000
# Epoch 2/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 2935001.2500 - val_loss: 1884483.1250
# Epoch 3/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1551662.2500 - val_loss: 676709.0000
# Epoch 4/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 480123.8125 - val_loss: 83660.4766
# Epoch 5/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 43438.6875 - val_loss: 442.2622
# Epoch 6/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 181.9567 - val_loss: 75.6197
# Epoch 7/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 76.6853 - val_loss: 76.2160
# Epoch 8/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 76.2267 - val_loss: 75.4202
# Epoch 9/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 77.0505 - val_loss: 77.5758
# Epoch 10/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 73.6345 - val_loss: 73.3670
# Epoch 11/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 72.8254 - val_loss: 74.2874
# Epoch 12/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 73.7497 - val_loss: 74.9371
# Epoch 13/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 71.4355 - val_loss: 74.2243
# Epoch 14/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 69.9259 - val_loss: 73.8146
# Epoch 15/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 70.5106 - val_loss: 73.7752
# Epoch 16/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 69.2630 - val_loss: 74.8042
# Epoch 17/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 67.6730 - val_loss: 75.6304
# Epoch 18/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 67.1307 - val_loss: 77.1027
# Epoch 19/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 66.8417 - val_loss: 73.7654
# Epoch 20/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 65.2375 - val_loss: 72.5163
# Epoch 21/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 64.5000 - val_loss: 72.9470
# Epoch 22/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 64.6326 - val_loss: 72.4972
# Epoch 23/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 62.6778 - val_loss: 75.8728
# Epoch 24/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 63.0626 - val_loss: 73.8322
# Epoch 25/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 62.0434 - val_loss: 74.5543
# Epoch 26/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 61.5094 - val_loss: 74.0214
# Epoch 27/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 60.4195 - val_loss: 75.2071
# Epoch 28/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 60.2394 - val_loss: 74.1912
# Epoch 29/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 60.2904 - val_loss: 75.5642
# Epoch 30/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 59.7638 - val_loss: 73.9060
# Epoch 31/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 59.2366 - val_loss: 74.1523
# Epoch 32/50
# 2066/2066 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 57.7871 - val_loss: 76.6589
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# RMSE: 8.514530023057981

# %%
### 8.58 LAB - COMPETENCIA: 8.92 DIF = 0.21
test_data2 = pd.read_csv('testReg.csv')
test_ids = test_data2['ID'].copy()
test_data = test_data[selected_features2]

# Asumiendo que 'scaler' y 'model' ya están definidos y entrenados
X_test_scaled = scaler.transform(test_data)
predictions = model.predict(X_test_scaled).flatten()

# Creación de un DataFrame para guardar las predicciones junto con los IDs
output = pd.DataFrame({'ID': test_ids, 'Y': np.round(predictions).astype(int)})
output.to_csv('predictions2704f.csv', index=False)
print("Predicciones guardadas en 'predictionsfinalfinal.csv'.")
# Out:
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Predicciones guardadas en 'predictionsfinalfinal.csv'.

# %%
### RMSE 8.429 en LAB y 8.73 en Competencia.
